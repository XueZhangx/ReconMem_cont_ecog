# %%
import numpy as np
import pandas as pd
from scipy import stats
import os, random

# %%
# Specify the directories and layer inresults_dirtion
results_dir = '.'

# %%
target_img_info = pd.read_csv((os.path.join(results_dir, 'selected_imgs_sEEG.csv')))

# %%
filler_img_info = pd.read_csv(os.path.join(results_dir, 'filler_imgs_sEEG.csv'))

# %%
# Specify the parameters
n_imgs_per_cond = 15
cond_dict = {1:'Large RE, Small Dist',
            2:'Large RE, Large Dist',
            3:'Small RE, Small Dist',
            4:'Small RE, Large Dist'}
trials_per_block = 150
total_blocks = 13

# %%
repeated_fillers = filler_img_info.iloc[:5*total_blocks]
nonrepeat_fillers = filler_img_info.iloc[5*total_blocks:].reset_index(drop=True)

# %%
nonrepeat_fillers
# Out:
#      Unnamed: 0        Index Image type  Image index  Distinctiveness  \
# 0            65  Target-1834     Target         1834       975.457656
# 1            66  Target-1858     Target         1858      1016.735708
# 2            67  Target-1861     Target         1861       971.274677
# 3            68  Target-1874     Target         1874       968.407731
# 4            69  Target-1903     Target         1903       978.725316
# ..          ...          ...        ...          ...              ...
# 354         419  Filler-7899     Filler         7899      1020.030821
# 355         420  Filler-7919     Filler         7919      1000.305747
# 356         421  Filler-7937     Filler         7937      1068.147854
# 357         422  Filler-7982     Filler         7982       967.068730
# 358         423  Filler-8008     Filler         8008       962.119628
#
#      Reconstruction error  Distinctiveness rank  RE rank
# 0                0.044887                4656.0   4622.0
# 1                0.047515                5330.0   5351.0
# 2                0.048557                4576.0   5611.0
# 3                0.045017                4526.0   4664.0
# 4                0.046014                4730.0   4918.0
# ..                    ...                   ...      ...
# 354              0.044740                5389.0   4576.0
# 355              0.046899                5071.0   5178.0
# 356              0.048969                6230.0   5709.0
# 357              0.046906                4511.0   5183.0
# 358              0.048335                4441.0   5556.0
#
# [359 rows x 8 columns]

# %%
# Sort the images into different groups
Large_RE_Small_Dist = target_img_info[(target_img_info['RE group']=='Large')&
                                     (target_img_info['Dist group']=='Small')].sort_values(by='Reconstruction error', ascending=False).reset_index(drop=True)
Large_RE_Large_Dist = target_img_info[(target_img_info['RE group']=='Large')&
                                     (target_img_info['Dist group']=='Large')].sort_values(by='Reconstruction error', ascending=False).reset_index(drop=True)
Small_RE_Small_Dist = target_img_info[(target_img_info['RE group']=='Large')&
                                     (target_img_info['Dist group']=='Small')].sort_values(by='Reconstruction error').reset_index(drop=True)
Small_RE_Large_Dist = target_img_info[(target_img_info['RE group']=='Large')&
                                     (target_img_info['Dist group']=='Large')].sort_values(by='Reconstruction error').reset_index(drop=True)

# %%
Large_RE_Small_Dist
# Out:
#      Unnamed: 0        Index Image type  Image index  Distinctiveness  \
# 0           167  Filler-6188     Filler         6188       535.458801
# 1            41  Target-1458     Target         1458       535.458801
# 2            10   Target-270     Target          270       801.236621
# 3           174  Filler-6435     Filler         6435       604.342811
# 4           131  Filler-4507     Filler         4507       777.991300
# ..          ...          ...        ...          ...              ...
# 190         187  Filler-7517     Filler         7517       716.469427
# 191         190  Filler-7648     Filler         7648       737.341632
# 192          50  Target-1988     Target         1988       796.959918
# 193         103  Filler-2269     Filler         2269       736.400173
# 194          65   Filler-426     Filler          426       575.695015
#
#      Reconstruction error  Distinctiveness rank  RE rank RE group Dist group  \
# 0                0.106418                 564.5  10278.0    Large      Small
# 1                0.105238                 564.5  10265.0    Large      Small
# 2                0.104338                2383.0  10259.0    Large      Small
# 3                0.102195                 900.0  10241.0    Large      Small
# 4                0.097216                2150.0  10175.0    Large      Small
# ..                    ...                   ...      ...      ...        ...
# 190              0.058820                1607.0   7850.0    Large      Small
# 191              0.058792                1784.0   7846.0    Large      Small
# 192              0.058760                2334.0   7841.0    Large      Small
# 193              0.058728                1774.0   7835.0    Large      Small
# 194              0.058718                 754.0   7832.0    Large      Small
#
#      Rank diff  Rank sum
# 0          NaN       NaN
# 1          NaN       NaN
# 2          NaN       NaN
# 3          NaN       NaN
# 4          NaN       NaN
# ..         ...       ...
# 190        NaN       NaN
# 191        NaN       NaN
# 192        NaN       NaN
# 193        NaN       NaN
# 194        NaN       NaN
#
# [195 rows x 12 columns]

# %%
img_cond_dict = {1:Large_RE_Small_Dist,
                2:Large_RE_Large_Dist,
                3:Small_RE_Small_Dist,
                4:Small_RE_Large_Dist}

# %% [markdown]
# 1. Memorability effect is quite robust at different memory lags. Maybe let's just try to repeat the target images at lages of 20-40. We should make sure that the mean repetition lag doesn't differ across the four groups of images.
# 2. We can have filler images (i.e. those that are not part of the four groups) that repeat at a shorter timescale (1-3), as an attention check.
# 3. Because it may be tiring to do the task all in one go, we can break the task in to 4 blocks of 7 minutes each.
# Each block consists of 17 images from each of the target image group (therefore 68 in total), 5 filler images that repeat at short timescle, and 30 fller images that never repeat. This leads to a total of 176 trials each.
# 4. Following Lin et al. (2021, Cognition), each image will be presented for 1.2 s and ITI is 1.2
# Therefore, each block will last about 7 mins (422.4 seconds).
# 5. Filler images can be sampled from the filler_images dataframe, which are images with RE and Dist in the middle.
# The experiment dataframe should consist of the following columns: block number, trial number, image index, trial type (old or new), response (empty for now) and reaction time (empty for now)

# %%
def generate_trial_sequence(
    num_conditions=4,
    images_per_condition=15,
    target_repeat_lag_range=(20, 40),
    num_filler_single=20,
    num_filler_repeat=5,
    filler_repeat_lag_range=(1, 3),
    total_trials=150,
    seed=None,
    max_repeats_in_last_n=6,
    check_last_n=10
):
    if seed is not None:
        random.seed(seed)

    # 1. Generate image labels
    target_images = [
        f'T{cond}_{i}' for cond in range(1, num_conditions + 1)
        for i in range(1, images_per_condition + 1)
    ]
    filler_single = [f'F_S{i}' for i in range(1, num_filler_single + 1)]
    filler_repeat = [f'F_R{i}' for i in range(1, num_filler_repeat + 1)]

    sequence = [None] * total_trials
    used_positions = set()

    # ---------- new：record img_pairs & single_filter' positions ----------
    repeat_pairs = {}          # img -> (first_idx, second_idx)
    single_positions = []      # 所有 single-filler 的 idx（只记一次）

    def place_with_lag(img, min_lag, max_lag, total_len):
        attempts = 0
        while attempts < 1000:
            pos1 = random.randint(0, total_len - min_lag - 1)
            lag = random.randint(min_lag, max_lag)
            pos2 = pos1 + lag
            if pos2 >= total_len:
                attempts += 1
                continue
            if pos1 not in used_positions and pos2 not in used_positions:
                return pos1, pos2
            attempts += 1
        return None, None

    # 2. Place target images
    for img in target_images:
        pos1, pos2 = place_with_lag(img, *target_repeat_lag_range, total_trials)
        if pos1 is None:
            raise RuntimeError(f"Could not place target {img}")
        sequence[pos1] = (img, False)
        sequence[pos2] = (img, True)
        used_positions.update([pos1, pos2])
        ##---------- new：record repeat_img_pairs' positions ----------
        repeat_pairs[img] = (pos1, pos2)

    # 3. Place repeating fillers
    for img in filler_repeat:
        pos1, pos2 = place_with_lag(img, *filler_repeat_lag_range, total_trials)
        if pos1 is None:
            raise RuntimeError(f"Could not place repeating filler {img}")
        sequence[pos1] = (img, False)
        sequence[pos2] = (img, True)
        used_positions.update([pos1, pos2])
        ##---------- new：record repeat_img_pairs' positions ----------
        repeat_pairs[img] = (pos1, pos2)

    # 4. Place non-repeating fillers
    remaining_slots = [i for i in range(total_trials) if i not in used_positions]
    if len(remaining_slots) < num_filler_single:
        raise RuntimeError("Not enough slots for single fillers")
    random.shuffle(remaining_slots)


    for i, img in enumerate(filler_single):
        pos = remaining_slots[i]
        sequence[pos] = (img, False)
        used_positions.add(pos)
        ##----------- record single filter's position ----------
        single_positions.append(pos) ## record single filter's position

    # 5. Post-hoc check: Too many repeats at the end?
    def count_repeats(trial_list, start):
        return sum(1 for t in trial_list[start:] if t and t[1] is True)

    last_n_start = total_trials - check_last_n
    repeat_count = count_repeats(sequence, last_n_start)

    ##---------------------new-------------------------------------------
    def move_tail_repeats_with_single(sequence, single_pos, repeat_pairs, max_repeats_in_last_n, check_last_n, total = total_trials):
        last_start = total - check_last_n

        tail_second = [i for i in range(last_start, total) if sequence[i] and sequence[i][1] is True]
        need = len(tail_second) - max_repeats_in_last_n

        # pick 0-139  single filler
        candidates = sorted([i for i in single_pos if i < last_start and sequence[i]])
        for _ in range(need):
            if not candidates or not tail_second:
                break
            dst_second = tail_second.pop()
            src_single = candidates.pop(0)
            img = sequence[dst_second][0]
            first_repeat = repeat_pairs[img][0]

            # =====after swap need make sure: first ≤ second =====
            if src_single > first_repeat:
                sequence[src_single], sequence[dst_second] = sequence[dst_second], sequence[src_single]
                repeat_pairs[img] = (first_repeat, src_single)

            else:
                sequence[src_single], sequence[dst_second] = sequence[dst_second], sequence[src_single]
                new_first_repeat = src_single
                new_second_repeat = first_repeat
                repeat_pairs[img] = (new_first_repeat , new_second_repeat)
                sequence[new_first_repeat] = (img, False)
                sequence[new_second_repeat] = (img, True)
                continue


    if repeat_count > max_repeats_in_last_n:
        move_tail_repeats_with_single(
            sequence, single_positions, repeat_pairs,
            max_repeats_in_last_n, check_last_n, total_trials)


    # if repeat_count > max_repeats_in_last_n:
    #     # Try to reduce by swapping
    #     early_idxs = [i for i in range(total_trials - check_last_n) if sequence[i] and sequence[i][1] is False]
    #     late_idxs = [i for i in range(last_n_start, total_trials) if sequence[i] and sequence[i][1] is True]
    #
    #     swaps_done = 0
    #     for late_idx in late_idxs:
    #         for early_idx in early_idxs:
    #             # Swap early non-repeat with late repeat
    #             sequence[early_idx], sequence[late_idx] = sequence[late_idx], sequence[early_idx]
    #             new_repeat_count = count_repeats(sequence, last_n_start)
    #             if new_repeat_count <= max_repeats_in_last_n:
    #                 swaps_done += 1
    #                 break
    #             else:
    #                 # Revert and try next
    #                 sequence[early_idx], sequence[late_idx] = sequence[late_idx], sequence[early_idx]
    #         if count_repeats(sequence, last_n_start) <= max_repeats_in_last_n:
    #             break

    # Final check
    if count_repeats(sequence, last_n_start) > max_repeats_in_last_n:
        raise RuntimeError("Could not enforce repeat constraint in last trials")

    # 6. Format output
    final_sequence = []
    for i, trial in enumerate(sequence):
        if trial is None:
            final_sequence.append({
                'trial_num': i + 1,
                'image': None,
                'is_repeat': None,
                'type': 'EMPTY'
            })
        else:
            img, is_repeat = trial
            trial_type = 'target' if img.startswith('T') else 'filler'
            final_sequence.append({
                'trial_num': i + 1,
                'image': img,
                'is_repeat': is_repeat,
                'type': trial_type
            })

    return final_sequence

# %%
def generate_valid_sequence(max_attempts=100, verbose=True):
    for attempt in range(max_attempts):
        seed = random.randint(0, 1000000)
        try:
            sequence = generate_trial_sequence(seed=seed)
            if verbose:
                print(f"✅ Sequence generated successfully on attempt {attempt+1} (seed={seed})")
            return sequence
        except RuntimeError as e:
            if verbose:
                print(f"⚠️ Attempt {attempt+1} failed (seed={seed}): {str(e)}")
    raise RuntimeError("❌ Failed to generate a valid sequence after multiple attempts.")

# %%
for curr_block in range(total_blocks):
    # Generate trial sequence
    
    block_sequence_dict = generate_valid_sequence()
    
    # Place the images
    if curr_block != 12:
        df_t1 = img_cond_dict[1].iloc[curr_block*n_imgs_per_cond:(curr_block+1)*n_imgs_per_cond]
        df_t2 = img_cond_dict[2].iloc[curr_block*n_imgs_per_cond:(curr_block+1)*n_imgs_per_cond]
        df_t3 = img_cond_dict[3].iloc[curr_block*n_imgs_per_cond:(curr_block+1)*n_imgs_per_cond]
        df_t4 = img_cond_dict[4].iloc[curr_block*n_imgs_per_cond:(curr_block+1)*n_imgs_per_cond]
        df_f_single = nonrepeat_fillers.iloc[curr_block*20:(curr_block+1)*20]
        df_f_repeat = repeated_fillers.iloc[curr_block*5:(curr_block+1)*5]
    else:
        df_t1 = img_cond_dict[1].iloc[curr_block*n_imgs_per_cond:]
        df_t2 = img_cond_dict[2].iloc[curr_block*n_imgs_per_cond:]
        df_t3 = img_cond_dict[3].iloc[curr_block*n_imgs_per_cond:]
        df_t4 = img_cond_dict[4].iloc[curr_block*n_imgs_per_cond:]
        df_f_single = nonrepeat_fillers.iloc[curr_block*20:]
        df_f_repeat = repeated_fillers.iloc[curr_block*5:]
    
    # Step 1: Build a lookup dictionary for images
    image_lookup = {}
    # Target conditions
    for i, df in enumerate([df_t1, df_t2, df_t3, df_t4], start=1):
        for j, path in enumerate(df['Index']):
            label = f'T{i}_{j+1}'  # matches label from generate_trial_sequence
            image_lookup[label] = path

    # Fillers - single appearance
    for i, path in enumerate(df_f_single['Index'], start=1):
        label = f'F_S{i}'
        image_lookup[label] = path

    # Fillers - repeating
    for i, path in enumerate(df_f_repeat['Index'], start=1):
        label = f'F_R{i}'
        image_lookup[label] = path

    # Step 2: Assign image paths to your generated sequence

    for trial in block_sequence_dict:
        label = trial['image']
        trial['Image Index'] = image_lookup.get(label, None)
    
    block_df = pd.DataFrame(block_sequence_dict)
    block_df['Block'] = curr_block+1
# Out:
# ✅ Sequence generated successfully on attempt 1 (seed=994372)
# ✅ Sequence generated successfully on attempt 1 (seed=91503)
# ✅ Sequence generated successfully on attempt 1 (seed=182177)
# ✅ Sequence generated successfully on attempt 1 (seed=934134)
# ✅ Sequence generated successfully on attempt 1 (seed=499715)
# ✅ Sequence generated successfully on attempt 1 (seed=815260)
# ✅ Sequence generated successfully on attempt 1 (seed=711984)
# ✅ Sequence generated successfully on attempt 1 (seed=593573)
# ✅ Sequence generated successfully on attempt 1 (seed=829160)
# ✅ Sequence generated successfully on attempt 1 (seed=463831)
# ✅ Sequence generated successfully on attempt 1 (seed=852748)
# ✅ Sequence generated successfully on attempt 1 (seed=947763)
# ✅ Sequence generated successfully on attempt 1 (seed=725611)

# %%
NB_dir   = os.getcwd()
PROJECT  = os.path.dirname(os.path.dirname(NB_dir))
# 实验数据目录
Exp_dir  = os.path.join(PROJECT, 'Experiment/')

os.makedirs(Exp_dir, exist_ok=True)
print("experiment_design directory：", Exp_dir)
# Out:
# experiment_design directory： /Users/xuezhang/Documents/SKKU/ReconMem_cont_ecog/Experiment/

# %%
for sub in range(1, 51):
    sub_dir = os.path.join(Exp_dir, f"sub-{sub:02d}")
    if not os.path.isdir(sub_dir):
        os.mkdir(sub_dir)
    for curr_block in range(total_blocks):
        # Generate trial sequence
        block_sequence_dict = generate_valid_sequence()

        # Place the images
        if curr_block != 12:
            df_t1 = img_cond_dict[1].iloc[curr_block*n_imgs_per_cond:(curr_block+1)*n_imgs_per_cond]
            df_t2 = img_cond_dict[2].iloc[curr_block*n_imgs_per_cond:(curr_block+1)*n_imgs_per_cond]
            df_t3 = img_cond_dict[3].iloc[curr_block*n_imgs_per_cond:(curr_block+1)*n_imgs_per_cond]
            df_t4 = img_cond_dict[4].iloc[curr_block*n_imgs_per_cond:(curr_block+1)*n_imgs_per_cond]
            df_f_single = nonrepeat_fillers.iloc[curr_block*20:(curr_block+1)*20]
            df_f_repeat = repeated_fillers.iloc[curr_block*5:(curr_block+1)*5]
        else:
            df_t1 = img_cond_dict[1].iloc[curr_block*n_imgs_per_cond:]
            df_t2 = img_cond_dict[2].iloc[curr_block*n_imgs_per_cond:]
            df_t3 = img_cond_dict[3].iloc[curr_block*n_imgs_per_cond:]
            df_t4 = img_cond_dict[4].iloc[curr_block*n_imgs_per_cond:]
            df_f_single = nonrepeat_fillers.iloc[curr_block*20:]
            df_f_repeat = repeated_fillers.iloc[curr_block*5:]

        # Step 1: Build a lookup dictionary for images
        image_lookup = {}
        # Target conditions
        for i, df in enumerate([df_t1, df_t2, df_t3, df_t4], start=1):
            for j, path in enumerate(df['Index']):
                label = f'T{i}_{j+1}'  # matches label from generate_trial_sequence
                image_lookup[label] = path

        # Fillers - single appearance
        for i, path in enumerate(df_f_single['Index'], start=1):
            label = f'F_S{i}'
            image_lookup[label] = path

        # Fillers - repeating
        for i, path in enumerate(df_f_repeat['Index'], start=1):
            label = f'F_R{i}'
            image_lookup[label] = path

        # Step 2: Assign image paths to your generated sequence

        for trial in block_sequence_dict:
            label = trial['image']
            trial['Image Index'] = image_lookup.get(label, None)

        block_df = pd.DataFrame(block_sequence_dict)
        block_df['Block'] = curr_block+1
        
        block_dir = os.path.join(sub_dir, f"Block{curr_block+1:02d}_info.csv")
        block_df.to_csv(block_dir)
# Out:
# ✅ Sequence generated successfully on attempt 1 (seed=845431)
# ✅ Sequence generated successfully on attempt 1 (seed=471842)
# ✅ Sequence generated successfully on attempt 1 (seed=660515)
# ✅ Sequence generated successfully on attempt 1 (seed=848018)
# ✅ Sequence generated successfully on attempt 1 (seed=61333)
# ✅ Sequence generated successfully on attempt 1 (seed=753699)
# ✅ Sequence generated successfully on attempt 1 (seed=477407)
# ✅ Sequence generated successfully on attempt 1 (seed=935540)
# ✅ Sequence generated successfully on attempt 1 (seed=205867)
# ✅ Sequence generated successfully on attempt 1 (seed=620230)
# ✅ Sequence generated successfully on attempt 1 (seed=7064)
# ✅ Sequence generated successfully on attempt 1 (seed=572555)
# ✅ Sequence generated successfully on attempt 1 (seed=513090)
# ✅ Sequence generated successfully on attempt 1 (seed=971951)
# ✅ Sequence generated successfully on attempt 1 (seed=941840)
# ✅ Sequence generated successfully on attempt 1 (seed=145909)
# ✅ Sequence generated successfully on attempt 1 (seed=398699)
# ✅ Sequence generated successfully on attempt 1 (seed=871017)
# ✅ Sequence generated successfully on attempt 1 (seed=431955)
# ✅ Sequence generated successfully on attempt 1 (seed=10604)
# ✅ Sequence generated successfully on attempt 1 (seed=885014)
# ✅ Sequence generated successfully on attempt 1 (seed=83503)
# ✅ Sequence generated successfully on attempt 1 (seed=270148)
# ✅ Sequence generated successfully on attempt 1 (seed=504130)
# ✅ Sequence generated successfully on attempt 1 (seed=147117)
# ✅ Sequence generated successfully on attempt 1 (seed=975062)
# ✅ Sequence generated successfully on attempt 1 (seed=740019)
# ✅ Sequence generated successfully on attempt 1 (seed=410972)
# ✅ Sequence generated successfully on attempt 1 (seed=457569)
# ✅ Sequence generated successfully on attempt 1 (seed=963697)
# ✅ Sequence generated successfully on attempt 1 (seed=772028)
# ✅ Sequence generated successfully on attempt 1 (seed=805809)
# ⚠️ Attempt 1 failed (seed=476937): Could not enforce repeat constraint in last trials
# ✅ Sequence generated successfully on attempt 2 (seed=831880)
# ✅ Sequence generated successfully on attempt 1 (seed=206545)
# ✅ Sequence generated successfully on attempt 1 (seed=829215)
# ✅ Sequence generated successfully on attempt 1 (seed=427246)
# ✅ Sequence generated successfully on attempt 1 (seed=464486)
# ✅ Sequence generated successfully on attempt 1 (seed=264987)
# ✅ Sequence generated successfully on attempt 1 (seed=377447)
# ✅ Sequence generated successfully on attempt 1 (seed=155131)
# ✅ Sequence generated successfully on attempt 1 (seed=774866)
# ✅ Sequence generated successfully on attempt 1 (seed=607475)
# ✅ Sequence generated successfully on attempt 1 (seed=841610)
# ✅ Sequence generated successfully on attempt 1 (seed=649703)
# ✅ Sequence generated successfully on attempt 1 (seed=998543)
# ✅ Sequence generated successfully on attempt 1 (seed=310186)
# ✅ Sequence generated successfully on attempt 1 (seed=684853)
# ✅ Sequence generated successfully on attempt 1 (seed=52424)
# ✅ Sequence generated successfully on attempt 1 (seed=535920)
# ✅ Sequence generated successfully on attempt 1 (seed=262180)
# ✅ Sequence generated successfully on attempt 1 (seed=400560)
# ✅ Sequence generated successfully on attempt 1 (seed=284064)
# ✅ Sequence generated successfully on attempt 1 (seed=410679)
# ✅ Sequence generated successfully on attempt 1 (seed=746123)
# ✅ Sequence generated successfully on attempt 1 (seed=575096)
# ✅ Sequence generated successfully on attempt 1 (seed=947241)
# ✅ Sequence generated successfully on attempt 1 (seed=584956)
# ✅ Sequence generated successfully on attempt 1 (seed=940232)
# ✅ Sequence generated successfully on attempt 1 (seed=661224)
# ✅ Sequence generated successfully on attempt 1 (seed=544592)
# ✅ Sequence generated successfully on attempt 1 (seed=773522)
# ✅ Sequence generated successfully on attempt 1 (seed=147973)
# ✅ Sequence generated successfully on attempt 1 (seed=712520)
# ✅ Sequence generated successfully on attempt 1 (seed=917792)
# ✅ Sequence generated successfully on attempt 1 (seed=500540)
# ✅ Sequence generated successfully on attempt 1 (seed=968944)
# ✅ Sequence generated successfully on attempt 1 (seed=908396)
# ⚠️ Attempt 1 failed (seed=195191): Could not enforce repeat constraint in last trials
# ✅ Sequence generated successfully on attempt 2 (seed=474471)
# ✅ Sequence generated successfully on attempt 1 (seed=786210)
# ✅ Sequence generated successfully on attempt 1 (seed=241311)
# ✅ Sequence generated successfully on attempt 1 (seed=87967)
# ✅ Sequence generated successfully on attempt 1 (seed=628918)
# ✅ Sequence generated successfully on attempt 1 (seed=698145)
# ✅ Sequence generated successfully on attempt 1 (seed=413827)
# ✅ Sequence generated successfully on attempt 1 (seed=622022)
# ✅ Sequence generated successfully on attempt 1 (seed=770314)
# ✅ Sequence generated successfully on attempt 1 (seed=49904)
# ✅ Sequence generated successfully on attempt 1 (seed=733401)
# ✅ Sequence generated successfully on attempt 1 (seed=785532)
# ✅ Sequence generated successfully on attempt 1 (seed=644408)
# ⚠️ Attempt 1 failed (seed=484057): Could not enforce repeat constraint in last trials
# ✅ Sequence generated successfully on attempt 2 (seed=654280)
# ✅ Sequence generated successfully on attempt 1 (seed=755544)
# ✅ Sequence generated successfully on attempt 1 (seed=675760)
# ✅ Sequence generated successfully on attempt 1 (seed=828074)
# ✅ Sequence generated successfully on attempt 1 (seed=457016)
# ✅ Sequence generated successfully on attempt 1 (seed=456352)
# ✅ Sequence generated successfully on attempt 1 (seed=493932)
# ✅ Sequence generated successfully on attempt 1 (seed=94751)
# ✅ Sequence generated successfully on attempt 1 (seed=285467)
# ✅ Sequence generated successfully on attempt 1 (seed=565644)
# ✅ Sequence generated successfully on attempt 1 (seed=698517)
# ✅ Sequence generated successfully on attempt 1 (seed=12384)
# ✅ Sequence generated successfully on attempt 1 (seed=433687)
# ✅ Sequence generated successfully on attempt 1 (seed=193322)
# ⚠️ Attempt 1 failed (seed=334572): Could not enforce repeat constraint in last trials
# ✅ Sequence generated successfully on attempt 2 (seed=656140)
# ✅ Sequence generated successfully on attempt 1 (seed=988039)
# ✅ Sequence generated successfully on attempt 1 (seed=569172)
# ✅ Sequence generated successfully on attempt 1 (seed=383769)
# ✅ Sequence generated successfully on attempt 1 (seed=464337)
# ✅ Sequence generated successfully on attempt 1 (seed=15354)
# ✅ Sequence generated successfully on attempt 1 (seed=544877)
# ✅ Sequence generated successfully on attempt 1 (seed=195651)
# ✅ Sequence generated successfully on attempt 1 (seed=411608)
# ✅ Sequence generated successfully on attempt 1 (seed=266749)
# ✅ Sequence generated successfully on attempt 1 (seed=238749)
# ✅ Sequence generated successfully on attempt 1 (seed=204905)
# ✅ Sequence generated successfully on attempt 1 (seed=31999)
# ⚠️ Attempt 1 failed (seed=416097): Could not enforce repeat constraint in last trials
# ⚠️ Attempt 2 failed (seed=307779): Could not enforce repeat constraint in last trials
# ✅ Sequence generated successfully on attempt 3 (seed=777709)
# ✅ Sequence generated successfully on attempt 1 (seed=577789)
# ✅ Sequence generated successfully on attempt 1 (seed=881484)
# ✅ Sequence generated successfully on attempt 1 (seed=989434)
# ✅ Sequence generated successfully on attempt 1 (seed=71947)
# ✅ Sequence generated successfully on attempt 1 (seed=520406)
# ✅ Sequence generated successfully on attempt 1 (seed=447622)
# ⚠️ Attempt 1 failed (seed=36993): Could not enforce repeat constraint in last trials
# ✅ Sequence generated successfully on attempt 2 (seed=867943)
# ✅ Sequence generated successfully on attempt 1 (seed=347844)
# ✅ Sequence generated successfully on attempt 1 (seed=330317)
# ✅ Sequence generated successfully on attempt 1 (seed=718654)
# ✅ Sequence generated successfully on attempt 1 (seed=623922)
# ✅ Sequence generated successfully on attempt 1 (seed=147736)
# ✅ Sequence generated successfully on attempt 1 (seed=323766)
# ✅ Sequence generated successfully on attempt 1 (seed=893456)
# ✅ Sequence generated successfully on attempt 1 (seed=649886)
# ✅ Sequence generated successfully on attempt 1 (seed=45997)
# ✅ Sequence generated successfully on attempt 1 (seed=420198)
# ✅ Sequence generated successfully on attempt 1 (seed=622599)
# ✅ Sequence generated successfully on attempt 1 (seed=803316)
# ✅ Sequence generated successfully on attempt 1 (seed=577942)
# ✅ Sequence generated successfully on attempt 1 (seed=311270)
# ✅ Sequence generated successfully on attempt 1 (seed=131259)
# ✅ Sequence generated successfully on attempt 1 (seed=139307)
# ✅ Sequence generated successfully on attempt 1 (seed=26549)
# ✅ Sequence generated successfully on attempt 1 (seed=133054)
# ✅ Sequence generated successfully on attempt 1 (seed=366058)
# ✅ Sequence generated successfully on attempt 1 (seed=398322)
# ✅ Sequence generated successfully on attempt 1 (seed=704930)
# ✅ Sequence generated successfully on attempt 1 (seed=989506)
# ✅ Sequence generated successfully on attempt 1 (seed=814088)
# ✅ Sequence generated successfully on attempt 1 (seed=209352)
# ✅ Sequence generated successfully on attempt 1 (seed=775709)
# ✅ Sequence generated successfully on attempt 1 (seed=640462)
# ✅ Sequence generated successfully on attempt 1 (seed=883186)
# ✅ Sequence generated successfully on attempt 1 (seed=259238)
# ✅ Sequence generated successfully on attempt 1 (seed=874705)
# ✅ Sequence generated successfully on attempt 1 (seed=307616)
# ✅ Sequence generated successfully on attempt 1 (seed=697269)
# ✅ Sequence generated successfully on attempt 1 (seed=399740)
# ✅ Sequence generated successfully on attempt 1 (seed=327784)
# ✅ Sequence generated successfully on attempt 1 (seed=925080)
# ✅ Sequence generated successfully on attempt 1 (seed=593565)
# ✅ Sequence generated successfully on attempt 1 (seed=298237)
# ✅ Sequence generated successfully on attempt 1 (seed=750287)
# ✅ Sequence generated successfully on attempt 1 (seed=151071)
# ✅ Sequence generated successfully on attempt 1 (seed=434539)
# ✅ Sequence generated successfully on attempt 1 (seed=661679)
# ✅ Sequence generated successfully on attempt 1 (seed=840845)
# ✅ Sequence generated successfully on attempt 1 (seed=860989)
# ✅ Sequence generated successfully on attempt 1 (seed=30522)
# ✅ Sequence generated successfully on attempt 1 (seed=74006)
# ✅ Sequence generated successfully on attempt 1 (seed=652756)
# ✅ Sequence generated successfully on attempt 1 (seed=893933)
# ✅ Sequence generated successfully on attempt 1 (seed=900741)
# ✅ Sequence generated successfully on attempt 1 (seed=15561)
# ✅ Sequence generated successfully on attempt 1 (seed=428905)
# ✅ Sequence generated successfully on attempt 1 (seed=311420)
# ⚠️ Attempt 1 failed (seed=929331): Could not enforce repeat constraint in last trials
# ✅ Sequence generated successfully on attempt 2 (seed=748429)
# ✅ Sequence generated successfully on attempt 1 (seed=393896)
# ✅ Sequence generated successfully on attempt 1 (seed=537200)
# ✅ Sequence generated successfully on attempt 1 (seed=908005)
# ⚠️ Attempt 1 failed (seed=7288): Could not enforce repeat constraint in last trials
# ✅ Sequence generated successfully on attempt 2 (seed=801151)
# ⚠️ Attempt 1 failed (seed=243221): Could not enforce repeat constraint in last trials
# ✅ Sequence generated successfully on attempt 2 (seed=6039)
# ✅ Sequence generated successfully on attempt 1 (seed=330106)
# ✅ Sequence generated successfully on attempt 1 (seed=836209)
# ✅ Sequence generated successfully on attempt 1 (seed=505077)
# ✅ Sequence generated successfully on attempt 1 (seed=573619)
# ⚠️ Attempt 1 failed (seed=377466): Could not enforce repeat constraint in last trials
# ✅ Sequence generated successfully on attempt 2 (seed=425904)
# ⚠️ Attempt 1 failed (seed=940861): Could not enforce repeat constraint in last trials
# ✅ Sequence generated successfully on attempt 2 (seed=678650)
# ✅ Sequence generated successfully on attempt 1 (seed=597285)
# ✅ Sequence generated successfully on attempt 1 (seed=858109)
# ✅ Sequence generated successfully on attempt 1 (seed=747885)
# ✅ Sequence generated successfully on attempt 1 (seed=500261)
# ✅ Sequence generated successfully on attempt 1 (seed=306627)
# ✅ Sequence generated successfully on attempt 1 (seed=328835)
# ✅ Sequence generated successfully on attempt 1 (seed=993800)
# ✅ Sequence generated successfully on attempt 1 (seed=213729)
# ✅ Sequence generated successfully on attempt 1 (seed=328427)
# ✅ Sequence generated successfully on attempt 1 (seed=162572)
# ✅ Sequence generated successfully on attempt 1 (seed=92058)
# ⚠️ Attempt 1 failed (seed=629975): Could not enforce repeat constraint in last trials
# ✅ Sequence generated successfully on attempt 2 (seed=710960)
# ✅ Sequence generated successfully on attempt 1 (seed=452891)
# ✅ Sequence generated successfully on attempt 1 (seed=750726)
# ⚠️ Attempt 1 failed (seed=708257): Could not enforce repeat constraint in last trials
# ✅ Sequence generated successfully on attempt 2 (seed=399241)
# ✅ Sequence generated successfully on attempt 1 (seed=584169)
# ⚠️ Attempt 1 failed (seed=181545): Could not enforce repeat constraint in last trials
# ✅ Sequence generated successfully on attempt 2 (seed=892667)
# ✅ Sequence generated successfully on attempt 1 (seed=452984)
# ✅ Sequence generated successfully on attempt 1 (seed=932900)
# ✅ Sequence generated successfully on attempt 1 (seed=180648)
# ✅ Sequence generated successfully on attempt 1 (seed=549395)
# ✅ Sequence generated successfully on attempt 1 (seed=993356)
# ✅ Sequence generated successfully on attempt 1 (seed=208351)
# ⚠️ Attempt 1 failed (seed=980682): Could not enforce repeat constraint in last trials
# ✅ Sequence generated successfully on attempt 2 (seed=220784)
# ✅ Sequence generated successfully on attempt 1 (seed=117357)
# ✅ Sequence generated successfully on attempt 1 (seed=246129)
# ✅ Sequence generated successfully on attempt 1 (seed=40271)
# ⚠️ Attempt 1 failed (seed=975232): Could not enforce repeat constraint in last trials
# ✅ Sequence generated successfully on attempt 2 (seed=768278)
# ⚠️ Attempt 1 failed (seed=741507): Could not enforce repeat constraint in last trials
# ✅ Sequence generated successfully on attempt 2 (seed=264157)
# ✅ Sequence generated successfully on attempt 1 (seed=648565)
# ✅ Sequence generated successfully on attempt 1 (seed=76589)
# ✅ Sequence generated successfully on attempt 1 (seed=144083)
# ✅ Sequence generated successfully on attempt 1 (seed=934277)
# ✅ Sequence generated successfully on attempt 1 (seed=814332)
# ✅ Sequence generated successfully on attempt 1 (seed=462739)
# ✅ Sequence generated successfully on attempt 1 (seed=123289)
# ✅ Sequence generated successfully on attempt 1 (seed=186287)
# ✅ Sequence generated successfully on attempt 1 (seed=739571)
# ✅ Sequence generated successfully on attempt 1 (seed=778100)
# ✅ Sequence generated successfully on attempt 1 (seed=831375)
# ✅ Sequence generated successfully on attempt 1 (seed=807218)
# ✅ Sequence generated successfully on attempt 1 (seed=302602)
# ✅ Sequence generated successfully on attempt 1 (seed=567996)
# ✅ Sequence generated successfully on attempt 1 (seed=436405)
# ✅ Sequence generated successfully on attempt 1 (seed=918131)
# ✅ Sequence generated successfully on attempt 1 (seed=510123)
# ✅ Sequence generated successfully on attempt 1 (seed=712193)
# ✅ Sequence generated successfully on attempt 1 (seed=738455)
# ✅ Sequence generated successfully on attempt 1 (seed=489565)
# ✅ Sequence generated successfully on attempt 1 (seed=334980)
# ✅ Sequence generated successfully on attempt 1 (seed=677721)
# ✅ Sequence generated successfully on attempt 1 (seed=994620)
# ✅ Sequence generated successfully on attempt 1 (seed=75377)
# ⚠️ Attempt 1 failed (seed=429642): Could not enforce repeat constraint in last trials
# ✅ Sequence generated successfully on attempt 2 (seed=511650)
# ✅ Sequence generated successfully on attempt 1 (seed=346473)
# ✅ Sequence generated successfully on attempt 1 (seed=977606)
# ✅ Sequence generated successfully on attempt 1 (seed=928707)
# ⚠️ Attempt 1 failed (seed=897708): Could not enforce repeat constraint in last trials
# ✅ Sequence generated successfully on attempt 2 (seed=846090)
# ✅ Sequence generated successfully on attempt 1 (seed=845616)
# ✅ Sequence generated successfully on attempt 1 (seed=711397)
# ✅ Sequence generated successfully on attempt 1 (seed=314509)
# ✅ Sequence generated successfully on attempt 1 (seed=410473)
# ✅ Sequence generated successfully on attempt 1 (seed=274333)
# ✅ Sequence generated successfully on attempt 1 (seed=153678)
# ✅ Sequence generated successfully on attempt 1 (seed=826387)
# ✅ Sequence generated successfully on attempt 1 (seed=676811)
# ✅ Sequence generated successfully on attempt 1 (seed=104559)
# ✅ Sequence generated successfully on attempt 1 (seed=812875)
# ✅ Sequence generated successfully on attempt 1 (seed=1031)
# ⚠️ Attempt 1 failed (seed=942805): Could not enforce repeat constraint in last trials
# ⚠️ Attempt 2 failed (seed=473022): Could not enforce repeat constraint in last trials
# ✅ Sequence generated successfully on attempt 3 (seed=929841)
# ✅ Sequence generated successfully on attempt 1 (seed=543270)
# ✅ Sequence generated successfully on attempt 1 (seed=554089)
# ✅ Sequence generated successfully on attempt 1 (seed=512648)
# ⚠️ Attempt 1 failed (seed=737199): Could not enforce repeat constraint in last trials
# ✅ Sequence generated successfully on attempt 2 (seed=710673)
# ✅ Sequence generated successfully on attempt 1 (seed=373666)
# ✅ Sequence generated successfully on attempt 1 (seed=384439)
# ✅ Sequence generated successfully on attempt 1 (seed=401662)
# ✅ Sequence generated successfully on attempt 1 (seed=826219)
# ✅ Sequence generated successfully on attempt 1 (seed=2203)
# ✅ Sequence generated successfully on attempt 1 (seed=818310)
# ✅ Sequence generated successfully on attempt 1 (seed=901586)
# ✅ Sequence generated successfully on attempt 1 (seed=874786)
# ✅ Sequence generated successfully on attempt 1 (seed=203607)
# ✅ Sequence generated successfully on attempt 1 (seed=260336)
# ✅ Sequence generated successfully on attempt 1 (seed=333716)
# ✅ Sequence generated successfully on attempt 1 (seed=577220)
# ⚠️ Attempt 1 failed (seed=578432): Could not enforce repeat constraint in last trials
# ✅ Sequence generated successfully on attempt 2 (seed=511655)
# ✅ Sequence generated successfully on attempt 1 (seed=542835)
# ✅ Sequence generated successfully on attempt 1 (seed=235107)
# ✅ Sequence generated successfully on attempt 1 (seed=110723)
# ✅ Sequence generated successfully on attempt 1 (seed=231298)
# ✅ Sequence generated successfully on attempt 1 (seed=736263)
# ✅ Sequence generated successfully on attempt 1 (seed=436015)
# ✅ Sequence generated successfully on attempt 1 (seed=38083)
# ✅ Sequence generated successfully on attempt 1 (seed=649493)
# ✅ Sequence generated successfully on attempt 1 (seed=943441)
# ✅ Sequence generated successfully on attempt 1 (seed=269526)
# ✅ Sequence generated successfully on attempt 1 (seed=286113)
# ✅ Sequence generated successfully on attempt 1 (seed=623708)
# ✅ Sequence generated successfully on attempt 1 (seed=546791)
# ✅ Sequence generated successfully on attempt 1 (seed=751146)
# ✅ Sequence generated successfully on attempt 1 (seed=655800)
# ✅ Sequence generated successfully on attempt 1 (seed=145421)
# ✅ Sequence generated successfully on attempt 1 (seed=655196)
# ✅ Sequence generated successfully on attempt 1 (seed=368888)
# ✅ Sequence generated successfully on attempt 1 (seed=984464)
# ✅ Sequence generated successfully on attempt 1 (seed=138366)
# ✅ Sequence generated successfully on attempt 1 (seed=511784)
# ✅ Sequence generated successfully on attempt 1 (seed=340617)
# ✅ Sequence generated successfully on attempt 1 (seed=317476)
# ✅ Sequence generated successfully on attempt 1 (seed=322594)
# ✅ Sequence generated successfully on attempt 1 (seed=238143)
# ⚠️ Attempt 1 failed (seed=854192): Could not enforce repeat constraint in last trials
# ✅ Sequence generated successfully on attempt 2 (seed=944537)
# ✅ Sequence generated successfully on attempt 1 (seed=112887)
# ✅ Sequence generated successfully on attempt 1 (seed=204431)
# ⚠️ Attempt 1 failed (seed=786056): Could not enforce repeat constraint in last trials
# ✅ Sequence generated successfully on attempt 2 (seed=876891)
# ✅ Sequence generated successfully on attempt 1 (seed=642683)
# ✅ Sequence generated successfully on attempt 1 (seed=227879)
# ✅ Sequence generated successfully on attempt 1 (seed=278058)
# ✅ Sequence generated successfully on attempt 1 (seed=778650)
# ✅ Sequence generated successfully on attempt 1 (seed=996545)
# ✅ Sequence generated successfully on attempt 1 (seed=605887)
# ✅ Sequence generated successfully on attempt 1 (seed=473845)
# ✅ Sequence generated successfully on attempt 1 (seed=45343)
# ✅ Sequence generated successfully on attempt 1 (seed=744112)
# ✅ Sequence generated successfully on attempt 1 (seed=147455)
# ✅ Sequence generated successfully on attempt 1 (seed=534477)
# ✅ Sequence generated successfully on attempt 1 (seed=980719)
# ✅ Sequence generated successfully on attempt 1 (seed=142829)
# ✅ Sequence generated successfully on attempt 1 (seed=328492)
# ✅ Sequence generated successfully on attempt 1 (seed=893562)
# ✅ Sequence generated successfully on attempt 1 (seed=282004)
# ✅ Sequence generated successfully on attempt 1 (seed=224089)
# ✅ Sequence generated successfully on attempt 1 (seed=895595)
# ✅ Sequence generated successfully on attempt 1 (seed=346736)
# ⚠️ Attempt 1 failed (seed=422794): Could not enforce repeat constraint in last trials
# ✅ Sequence generated successfully on attempt 2 (seed=483216)
# ✅ Sequence generated successfully on attempt 1 (seed=864507)
# ✅ Sequence generated successfully on attempt 1 (seed=711139)
# ✅ Sequence generated successfully on attempt 1 (seed=791383)
# ✅ Sequence generated successfully on attempt 1 (seed=490506)
# ✅ Sequence generated successfully on attempt 1 (seed=303308)
# ⚠️ Attempt 1 failed (seed=139717): Could not enforce repeat constraint in last trials
# ✅ Sequence generated successfully on attempt 2 (seed=853971)
# ✅ Sequence generated successfully on attempt 1 (seed=97019)
# ✅ Sequence generated successfully on attempt 1 (seed=21052)
# ✅ Sequence generated successfully on attempt 1 (seed=984295)
# ✅ Sequence generated successfully on attempt 1 (seed=931496)
# ✅ Sequence generated successfully on attempt 1 (seed=466187)
# ✅ Sequence generated successfully on attempt 1 (seed=557683)
# ✅ Sequence generated successfully on attempt 1 (seed=35935)
# ✅ Sequence generated successfully on attempt 1 (seed=291756)
# ✅ Sequence generated successfully on attempt 1 (seed=834907)
# ✅ Sequence generated successfully on attempt 1 (seed=73332)
# ✅ Sequence generated successfully on attempt 1 (seed=434669)
# ✅ Sequence generated successfully on attempt 1 (seed=912155)
# ✅ Sequence generated successfully on attempt 1 (seed=741702)
# ✅ Sequence generated successfully on attempt 1 (seed=288284)
# ✅ Sequence generated successfully on attempt 1 (seed=987456)
# ✅ Sequence generated successfully on attempt 1 (seed=916425)
# ✅ Sequence generated successfully on attempt 1 (seed=710278)
# ✅ Sequence generated successfully on attempt 1 (seed=543297)
# ✅ Sequence generated successfully on attempt 1 (seed=966160)
# ✅ Sequence generated successfully on attempt 1 (seed=320287)
# ✅ Sequence generated successfully on attempt 1 (seed=456201)
# ✅ Sequence generated successfully on attempt 1 (seed=763587)
# ✅ Sequence generated successfully on attempt 1 (seed=711757)
# ✅ Sequence generated successfully on attempt 1 (seed=447599)
# ✅ Sequence generated successfully on attempt 1 (seed=487805)
# ✅ Sequence generated successfully on attempt 1 (seed=735108)
# ✅ Sequence generated successfully on attempt 1 (seed=241504)
# ✅ Sequence generated successfully on attempt 1 (seed=759843)
# ✅ Sequence generated successfully on attempt 1 (seed=634466)
# ✅ Sequence generated successfully on attempt 1 (seed=716353)
# ✅ Sequence generated successfully on attempt 1 (seed=847777)
# ✅ Sequence generated successfully on attempt 1 (seed=919060)
# ✅ Sequence generated successfully on attempt 1 (seed=914905)
# ✅ Sequence generated successfully on attempt 1 (seed=342499)
# ✅ Sequence generated successfully on attempt 1 (seed=316645)
# ✅ Sequence generated successfully on attempt 1 (seed=602819)
# ✅ Sequence generated successfully on attempt 1 (seed=115024)
# ⚠️ Attempt 1 failed (seed=737591): Could not enforce repeat constraint in last trials
# ✅ Sequence generated successfully on attempt 2 (seed=730020)
# ✅ Sequence generated successfully on attempt 1 (seed=93463)
# ✅ Sequence generated successfully on attempt 1 (seed=733623)
# ✅ Sequence generated successfully on attempt 1 (seed=915884)
# ✅ Sequence generated successfully on attempt 1 (seed=703072)
# ✅ Sequence generated successfully on attempt 1 (seed=778331)
# ✅ Sequence generated successfully on attempt 1 (seed=795112)
# ✅ Sequence generated successfully on attempt 1 (seed=700728)
# ✅ Sequence generated successfully on attempt 1 (seed=337868)
# ✅ Sequence generated successfully on attempt 1 (seed=961873)
# ✅ Sequence generated successfully on attempt 1 (seed=922522)
# ✅ Sequence generated successfully on attempt 1 (seed=779277)
# ⚠️ Attempt 1 failed (seed=273330): Could not enforce repeat constraint in last trials
# ✅ Sequence generated successfully on attempt 2 (seed=821218)
# ⚠️ Attempt 1 failed (seed=691422): Could not enforce repeat constraint in last trials
# ✅ Sequence generated successfully on attempt 2 (seed=121737)
# ✅ Sequence generated successfully on attempt 1 (seed=688276)
# ✅ Sequence generated successfully on attempt 1 (seed=68459)
# ✅ Sequence generated successfully on attempt 1 (seed=455276)
# ⚠️ Attempt 1 failed (seed=221071): Could not enforce repeat constraint in last trials
# ✅ Sequence generated successfully on attempt 2 (seed=543371)
# ✅ Sequence generated successfully on attempt 1 (seed=496544)
# ✅ Sequence generated successfully on attempt 1 (seed=403539)
# ✅ Sequence generated successfully on attempt 1 (seed=256527)
# ✅ Sequence generated successfully on attempt 1 (seed=459048)
# ⚠️ Attempt 1 failed (seed=6811): Could not enforce repeat constraint in last trials
# ✅ Sequence generated successfully on attempt 2 (seed=410277)
# ✅ Sequence generated successfully on attempt 1 (seed=351634)
# ✅ Sequence generated successfully on attempt 1 (seed=218537)
# ⚠️ Attempt 1 failed (seed=124868): Could not enforce repeat constraint in last trials
# ✅ Sequence generated successfully on attempt 2 (seed=370659)
# ⚠️ Attempt 1 failed (seed=857771): Could not enforce repeat constraint in last trials
# ✅ Sequence generated successfully on attempt 2 (seed=255912)
# ✅ Sequence generated successfully on attempt 1 (seed=732534)
# ✅ Sequence generated successfully on attempt 1 (seed=713)
# ✅ Sequence generated successfully on attempt 1 (seed=479941)
# ✅ Sequence generated successfully on attempt 1 (seed=986293)
# ✅ Sequence generated successfully on attempt 1 (seed=706324)
# ✅ Sequence generated successfully on attempt 1 (seed=461559)
# ✅ Sequence generated successfully on attempt 1 (seed=310050)
# ✅ Sequence generated successfully on attempt 1 (seed=948445)
# ✅ Sequence generated successfully on attempt 1 (seed=7285)
# ✅ Sequence generated successfully on attempt 1 (seed=983826)
# ✅ Sequence generated successfully on attempt 1 (seed=142337)
# ✅ Sequence generated successfully on attempt 1 (seed=260864)
# ✅ Sequence generated successfully on attempt 1 (seed=717282)
# ✅ Sequence generated successfully on attempt 1 (seed=802283)
# ⚠️ Attempt 1 failed (seed=976975): Could not enforce repeat constraint in last trials
# ⚠️ Attempt 2 failed (seed=828796): Could not enforce repeat constraint in last trials
# ✅ Sequence generated successfully on attempt 3 (seed=173787)
# ✅ Sequence generated successfully on attempt 1 (seed=622571)
# ✅ Sequence generated successfully on attempt 1 (seed=842110)
# ✅ Sequence generated successfully on attempt 1 (seed=367435)
# ✅ Sequence generated successfully on attempt 1 (seed=323142)
# ✅ Sequence generated successfully on attempt 1 (seed=643919)
# ✅ Sequence generated successfully on attempt 1 (seed=258057)
# ⚠️ Attempt 1 failed (seed=156184): Could not enforce repeat constraint in last trials
# ✅ Sequence generated successfully on attempt 2 (seed=108045)
# ✅ Sequence generated successfully on attempt 1 (seed=927337)
# ✅ Sequence generated successfully on attempt 1 (seed=491821)
# ✅ Sequence generated successfully on attempt 1 (seed=271750)
# ✅ Sequence generated successfully on attempt 1 (seed=317301)
# ✅ Sequence generated successfully on attempt 1 (seed=985746)
# ✅ Sequence generated successfully on attempt 1 (seed=569901)
# ✅ Sequence generated successfully on attempt 1 (seed=246416)
# ✅ Sequence generated successfully on attempt 1 (seed=267282)
# ⚠️ Attempt 1 failed (seed=667886): Could not enforce repeat constraint in last trials
# ✅ Sequence generated successfully on attempt 2 (seed=169893)
# ✅ Sequence generated successfully on attempt 1 (seed=453176)
# ✅ Sequence generated successfully on attempt 1 (seed=530262)
# ✅ Sequence generated successfully on attempt 1 (seed=637236)
# ✅ Sequence generated successfully on attempt 1 (seed=526052)
# ⚠️ Attempt 1 failed (seed=202197): Could not enforce repeat constraint in last trials
# ✅ Sequence generated successfully on attempt 2 (seed=610183)
# ✅ Sequence generated successfully on attempt 1 (seed=683496)
# ✅ Sequence generated successfully on attempt 1 (seed=835900)
# ✅ Sequence generated successfully on attempt 1 (seed=326421)
# ✅ Sequence generated successfully on attempt 1 (seed=998794)
# ✅ Sequence generated successfully on attempt 1 (seed=621341)
# ✅ Sequence generated successfully on attempt 1 (seed=631535)
# ✅ Sequence generated successfully on attempt 1 (seed=483325)
# ✅ Sequence generated successfully on attempt 1 (seed=359229)
# ✅ Sequence generated successfully on attempt 1 (seed=249057)
# ⚠️ Attempt 1 failed (seed=896346): Could not enforce repeat constraint in last trials
# ✅ Sequence generated successfully on attempt 2 (seed=148645)
# ✅ Sequence generated successfully on attempt 1 (seed=614904)
# ✅ Sequence generated successfully on attempt 1 (seed=506327)
# ✅ Sequence generated successfully on attempt 1 (seed=460374)
# ✅ Sequence generated successfully on attempt 1 (seed=92629)
# ✅ Sequence generated successfully on attempt 1 (seed=762598)
# ✅ Sequence generated successfully on attempt 1 (seed=450629)
# ✅ Sequence generated successfully on attempt 1 (seed=73522)
# ✅ Sequence generated successfully on attempt 1 (seed=776258)
# ✅ Sequence generated successfully on attempt 1 (seed=117728)
# ✅ Sequence generated successfully on attempt 1 (seed=709521)
# ✅ Sequence generated successfully on attempt 1 (seed=351743)
# ✅ Sequence generated successfully on attempt 1 (seed=697270)
# ⚠️ Attempt 1 failed (seed=910755): Could not enforce repeat constraint in last trials
# ✅ Sequence generated successfully on attempt 2 (seed=130504)
# ✅ Sequence generated successfully on attempt 1 (seed=30335)
# ✅ Sequence generated successfully on attempt 1 (seed=305288)
# ⚠️ Attempt 1 failed (seed=915996): Could not enforce repeat constraint in last trials
# ✅ Sequence generated successfully on attempt 2 (seed=994285)
# ✅ Sequence generated successfully on attempt 1 (seed=397730)
# ✅ Sequence generated successfully on attempt 1 (seed=525674)
# ✅ Sequence generated successfully on attempt 1 (seed=555366)
# ✅ Sequence generated successfully on attempt 1 (seed=359335)
# ✅ Sequence generated successfully on attempt 1 (seed=153560)
# ✅ Sequence generated successfully on attempt 1 (seed=494651)
# ✅ Sequence generated successfully on attempt 1 (seed=954757)
# ✅ Sequence generated successfully on attempt 1 (seed=291910)
# ✅ Sequence generated successfully on attempt 1 (seed=988070)
# ✅ Sequence generated successfully on attempt 1 (seed=149031)
# ⚠️ Attempt 1 failed (seed=436063): Could not enforce repeat constraint in last trials
# ✅ Sequence generated successfully on attempt 2 (seed=735927)
# ✅ Sequence generated successfully on attempt 1 (seed=238483)
# ✅ Sequence generated successfully on attempt 1 (seed=523639)
# ✅ Sequence generated successfully on attempt 1 (seed=671675)
# ✅ Sequence generated successfully on attempt 1 (seed=70323)
# ✅ Sequence generated successfully on attempt 1 (seed=222034)
# ✅ Sequence generated successfully on attempt 1 (seed=410342)
# ✅ Sequence generated successfully on attempt 1 (seed=387797)
# ✅ Sequence generated successfully on attempt 1 (seed=17230)
# ✅ Sequence generated successfully on attempt 1 (seed=662338)
# ✅ Sequence generated successfully on attempt 1 (seed=115394)
# ⚠️ Attempt 1 failed (seed=734160): Could not enforce repeat constraint in last trials
# ✅ Sequence generated successfully on attempt 2 (seed=966843)
# ✅ Sequence generated successfully on attempt 1 (seed=315180)
# ✅ Sequence generated successfully on attempt 1 (seed=44247)
# ⚠️ Attempt 1 failed (seed=712693): Could not enforce repeat constraint in last trials
# ✅ Sequence generated successfully on attempt 2 (seed=278048)
# ✅ Sequence generated successfully on attempt 1 (seed=996983)
# ✅ Sequence generated successfully on attempt 1 (seed=222208)
# ✅ Sequence generated successfully on attempt 1 (seed=341623)
# ✅ Sequence generated successfully on attempt 1 (seed=536901)
# ✅ Sequence generated successfully on attempt 1 (seed=860933)
# ✅ Sequence generated successfully on attempt 1 (seed=966932)
# ✅ Sequence generated successfully on attempt 1 (seed=526046)
# ✅ Sequence generated successfully on attempt 1 (seed=583566)
# ⚠️ Attempt 1 failed (seed=139920): Could not enforce repeat constraint in last trials
# ✅ Sequence generated successfully on attempt 2 (seed=980336)
# ✅ Sequence generated successfully on attempt 1 (seed=813006)
# ✅ Sequence generated successfully on attempt 1 (seed=950822)
# ✅ Sequence generated successfully on attempt 1 (seed=539465)
# ✅ Sequence generated successfully on attempt 1 (seed=774783)
# ✅ Sequence generated successfully on attempt 1 (seed=817502)
# ✅ Sequence generated successfully on attempt 1 (seed=181995)
# ✅ Sequence generated successfully on attempt 1 (seed=848685)
# ✅ Sequence generated successfully on attempt 1 (seed=119696)
# ✅ Sequence generated successfully on attempt 1 (seed=59317)
# ✅ Sequence generated successfully on attempt 1 (seed=412274)
# ✅ Sequence generated successfully on attempt 1 (seed=804561)
# ✅ Sequence generated successfully on attempt 1 (seed=610345)
# ✅ Sequence generated successfully on attempt 1 (seed=354376)
# ✅ Sequence generated successfully on attempt 1 (seed=720689)
# ✅ Sequence generated successfully on attempt 1 (seed=142486)
# ✅ Sequence generated successfully on attempt 1 (seed=104008)
# ✅ Sequence generated successfully on attempt 1 (seed=535025)
# ✅ Sequence generated successfully on attempt 1 (seed=343054)
# ✅ Sequence generated successfully on attempt 1 (seed=407708)
# ✅ Sequence generated successfully on attempt 1 (seed=575796)
# ✅ Sequence generated successfully on attempt 1 (seed=224272)
# ✅ Sequence generated successfully on attempt 1 (seed=286206)
# ✅ Sequence generated successfully on attempt 1 (seed=546448)
# ✅ Sequence generated successfully on attempt 1 (seed=148163)
# ✅ Sequence generated successfully on attempt 1 (seed=393091)
# ✅ Sequence generated successfully on attempt 1 (seed=499226)
# ✅ Sequence generated successfully on attempt 1 (seed=206410)
# ✅ Sequence generated successfully on attempt 1 (seed=914030)
# ✅ Sequence generated successfully on attempt 1 (seed=239781)
# ✅ Sequence generated successfully on attempt 1 (seed=670818)
# ✅ Sequence generated successfully on attempt 1 (seed=582839)
# ✅ Sequence generated successfully on attempt 1 (seed=378248)
# ✅ Sequence generated successfully on attempt 1 (seed=296366)
# ✅ Sequence generated successfully on attempt 1 (seed=464534)
# ✅ Sequence generated successfully on attempt 1 (seed=588237)
# ✅ Sequence generated successfully on attempt 1 (seed=271478)
# ✅ Sequence generated successfully on attempt 1 (seed=872418)
# ✅ Sequence generated successfully on attempt 1 (seed=396761)
# ✅ Sequence generated successfully on attempt 1 (seed=690133)
# ✅ Sequence generated successfully on attempt 1 (seed=507546)
# ✅ Sequence generated successfully on attempt 1 (seed=20817)
# ✅ Sequence generated successfully on attempt 1 (seed=238497)
# ✅ Sequence generated successfully on attempt 1 (seed=165640)
# ✅ Sequence generated successfully on attempt 1 (seed=770793)
# ✅ Sequence generated successfully on attempt 1 (seed=389825)
# ✅ Sequence generated successfully on attempt 1 (seed=781822)
# ✅ Sequence generated successfully on attempt 1 (seed=846739)
# ⚠️ Attempt 1 failed (seed=211438): Could not enforce repeat constraint in last trials
# ✅ Sequence generated successfully on attempt 2 (seed=923386)
# ✅ Sequence generated successfully on attempt 1 (seed=965887)
# ✅ Sequence generated successfully on attempt 1 (seed=950762)
# ✅ Sequence generated successfully on attempt 1 (seed=700667)
# ✅ Sequence generated successfully on attempt 1 (seed=337978)
# ✅ Sequence generated successfully on attempt 1 (seed=381660)
# ✅ Sequence generated successfully on attempt 1 (seed=126668)
# ✅ Sequence generated successfully on attempt 1 (seed=112837)
# ✅ Sequence generated successfully on attempt 1 (seed=438190)
# ✅ Sequence generated successfully on attempt 1 (seed=240368)
# ✅ Sequence generated successfully on attempt 1 (seed=743638)
# ✅ Sequence generated successfully on attempt 1 (seed=750780)
# ✅ Sequence generated successfully on attempt 1 (seed=252963)
# ✅ Sequence generated successfully on attempt 1 (seed=268894)
# ✅ Sequence generated successfully on attempt 1 (seed=75605)
# ✅ Sequence generated successfully on attempt 1 (seed=343684)
# ⚠️ Attempt 1 failed (seed=610263): Could not enforce repeat constraint in last trials
# ✅ Sequence generated successfully on attempt 2 (seed=574021)
# ⚠️ Attempt 1 failed (seed=502402): Could not enforce repeat constraint in last trials
# ✅ Sequence generated successfully on attempt 2 (seed=832811)
# ✅ Sequence generated successfully on attempt 1 (seed=629609)
# ✅ Sequence generated successfully on attempt 1 (seed=999018)
# ✅ Sequence generated successfully on attempt 1 (seed=876280)
# ✅ Sequence generated successfully on attempt 1 (seed=237490)
# ✅ Sequence generated successfully on attempt 1 (seed=812922)
# ✅ Sequence generated successfully on attempt 1 (seed=383143)
# ✅ Sequence generated successfully on attempt 1 (seed=162318)
# ✅ Sequence generated successfully on attempt 1 (seed=380735)
# ✅ Sequence generated successfully on attempt 1 (seed=801293)
# ⚠️ Attempt 1 failed (seed=906223): Could not enforce repeat constraint in last trials
# ✅ Sequence generated successfully on attempt 2 (seed=882394)
# ✅ Sequence generated successfully on attempt 1 (seed=95448)
# ✅ Sequence generated successfully on attempt 1 (seed=149739)
# ✅ Sequence generated successfully on attempt 1 (seed=230044)
# ✅ Sequence generated successfully on attempt 1 (seed=397733)
# ✅ Sequence generated successfully on attempt 1 (seed=56206)
# ✅ Sequence generated successfully on attempt 1 (seed=834248)
# ✅ Sequence generated successfully on attempt 1 (seed=861205)
# ✅ Sequence generated successfully on attempt 1 (seed=988267)
# ✅ Sequence generated successfully on attempt 1 (seed=116535)
# ✅ Sequence generated successfully on attempt 1 (seed=855267)
# ✅ Sequence generated successfully on attempt 1 (seed=173539)
# ✅ Sequence generated successfully on attempt 1 (seed=987688)
# ✅ Sequence generated successfully on attempt 1 (seed=571005)
# ✅ Sequence generated successfully on attempt 1 (seed=952299)
# ⚠️ Attempt 1 failed (seed=886607): Could not enforce repeat constraint in last trials
# ✅ Sequence generated successfully on attempt 2 (seed=471828)
# ✅ Sequence generated successfully on attempt 1 (seed=222547)
# ✅ Sequence generated successfully on attempt 1 (seed=791916)
# ✅ Sequence generated successfully on attempt 1 (seed=662564)
# ✅ Sequence generated successfully on attempt 1 (seed=107303)
# ✅ Sequence generated successfully on attempt 1 (seed=520215)
# ✅ Sequence generated successfully on attempt 1 (seed=113773)
# ✅ Sequence generated successfully on attempt 1 (seed=247933)
# ⚠️ Attempt 1 failed (seed=630602): Could not enforce repeat constraint in last trials
# ✅ Sequence generated successfully on attempt 2 (seed=12760)
# ✅ Sequence generated successfully on attempt 1 (seed=736401)
# ✅ Sequence generated successfully on attempt 1 (seed=13259)
# ⚠️ Attempt 1 failed (seed=866615): Could not enforce repeat constraint in last trials
# ✅ Sequence generated successfully on attempt 2 (seed=240086)
# ✅ Sequence generated successfully on attempt 1 (seed=453698)
# ✅ Sequence generated successfully on attempt 1 (seed=980000)
# ✅ Sequence generated successfully on attempt 1 (seed=890317)
# ✅ Sequence generated successfully on attempt 1 (seed=37180)
# ✅ Sequence generated successfully on attempt 1 (seed=2159)
# ✅ Sequence generated successfully on attempt 1 (seed=763201)
# ✅ Sequence generated successfully on attempt 1 (seed=870137)
# ✅ Sequence generated successfully on attempt 1 (seed=35077)
# ✅ Sequence generated successfully on attempt 1 (seed=597832)
# ✅ Sequence generated successfully on attempt 1 (seed=478732)
# ✅ Sequence generated successfully on attempt 1 (seed=68675)
# ⚠️ Attempt 1 failed (seed=793725): Could not enforce repeat constraint in last trials
# ✅ Sequence generated successfully on attempt 2 (seed=514647)
# ✅ Sequence generated successfully on attempt 1 (seed=454036)
# ✅ Sequence generated successfully on attempt 1 (seed=546289)
# ✅ Sequence generated successfully on attempt 1 (seed=109784)
# ✅ Sequence generated successfully on attempt 1 (seed=585975)
# ✅ Sequence generated successfully on attempt 1 (seed=37113)
# ✅ Sequence generated successfully on attempt 1 (seed=315695)
# ✅ Sequence generated successfully on attempt 1 (seed=686754)
# ✅ Sequence generated successfully on attempt 1 (seed=37515)
# ✅ Sequence generated successfully on attempt 1 (seed=768774)
# ✅ Sequence generated successfully on attempt 1 (seed=138638)
# ✅ Sequence generated successfully on attempt 1 (seed=823240)
# ✅ Sequence generated successfully on attempt 1 (seed=503080)
# ✅ Sequence generated successfully on attempt 1 (seed=276201)
# ✅ Sequence generated successfully on attempt 1 (seed=222286)
# ✅ Sequence generated successfully on attempt 1 (seed=637479)
# ✅ Sequence generated successfully on attempt 1 (seed=881940)
# ✅ Sequence generated successfully on attempt 1 (seed=346281)
# ✅ Sequence generated successfully on attempt 1 (seed=923050)
# ✅ Sequence generated successfully on attempt 1 (seed=981229)
# ✅ Sequence generated successfully on attempt 1 (seed=973471)
# ⚠️ Attempt 1 failed (seed=121725): Could not enforce repeat constraint in last trials
# ✅ Sequence generated successfully on attempt 2 (seed=546416)
# ✅ Sequence generated successfully on attempt 1 (seed=98154)
# ✅ Sequence generated successfully on attempt 1 (seed=303871)
# ✅ Sequence generated successfully on attempt 1 (seed=807094)
# ✅ Sequence generated successfully on attempt 1 (seed=106208)
# ✅ Sequence generated successfully on attempt 1 (seed=60129)
# ✅ Sequence generated successfully on attempt 1 (seed=768676)
# ✅ Sequence generated successfully on attempt 1 (seed=238788)
# ✅ Sequence generated successfully on attempt 1 (seed=737292)
# ✅ Sequence generated successfully on attempt 1 (seed=284785)
# ✅ Sequence generated successfully on attempt 1 (seed=811695)
# ✅ Sequence generated successfully on attempt 1 (seed=618530)
# ✅ Sequence generated successfully on attempt 1 (seed=171798)
# ✅ Sequence generated successfully on attempt 1 (seed=305288)
# ⚠️ Attempt 1 failed (seed=915996): Could not enforce repeat constraint in last trials
# ✅ Sequence generated successfully on attempt 2 (seed=994285)
# ✅ Sequence generated successfully on attempt 1 (seed=397730)
# ✅ Sequence generated successfully on attempt 1 (seed=525674)
# ✅ Sequence generated successfully on attempt 1 (seed=555366)
# ✅ Sequence generated successfully on attempt 1 (seed=359335)
# ✅ Sequence generated successfully on attempt 1 (seed=153560)
# ✅ Sequence generated successfully on attempt 1 (seed=494651)
# ✅ Sequence generated successfully on attempt 1 (seed=954757)
# ✅ Sequence generated successfully on attempt 1 (seed=291910)
# ✅ Sequence generated successfully on attempt 1 (seed=988070)
# ✅ Sequence generated successfully on attempt 1 (seed=149031)
# ⚠️ Attempt 1 failed (seed=436063): Could not enforce repeat constraint in last trials
# ✅ Sequence generated successfully on attempt 2 (seed=735927)
# ✅ Sequence generated successfully on attempt 1 (seed=238483)
# ✅ Sequence generated successfully on attempt 1 (seed=523639)
# ✅ Sequence generated successfully on attempt 1 (seed=671675)
# ✅ Sequence generated successfully on attempt 1 (seed=70323)
# ✅ Sequence generated successfully on attempt 1 (seed=222034)
# ✅ Sequence generated successfully on attempt 1 (seed=410342)
# ✅ Sequence generated successfully on attempt 1 (seed=387797)
# ✅ Sequence generated successfully on attempt 1 (seed=17230)
# ✅ Sequence generated successfully on attempt 1 (seed=662338)
# ✅ Sequence generated successfully on attempt 1 (seed=115394)
# ⚠️ Attempt 1 failed (seed=734160): Could not enforce repeat constraint in last trials
# ✅ Sequence generated successfully on attempt 2 (seed=966843)
# ✅ Sequence generated successfully on attempt 1 (seed=315180)

# %%
block1_df = pd.read_csv('../../Experiment/sub-01/Block01_info.csv')

# %%
block13_df = pd.read_csv('../../Experiment/sub-01/Block02_info.csv')

# %%
np.sum(block1_df['Image Index'].isin(block13_df['Image Index']))
# Out:
# np.int64(0)
