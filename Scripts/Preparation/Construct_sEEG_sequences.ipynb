# %%
import numpy as np
import pandas as pd
from scipy import stats
import statsmodels.api as sm
import os, random
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Specify the directories and layer inresults_dirtion
results_dir = '../Results/'

# %%
target_img_info = pd.read_csv((os.path.join(results_dir, 'selected_imgs_sEEG.csv')))

# %%
filler_img_info = pd.read_csv(os.path.join(results_dir, 'filler_imgs_sEEG.csv'))

# %%
# Specify the parameters
n_imgs_per_cond = 15
cond_dict = {1:'Large RE, Small Dist',
            2:'Large RE, Large Dist',
            3:'Small RE, Small Dist',
            4:'Small RE, Large Dist'}
trials_per_block = 150
total_blocks = 13

# %%
repeated_fillers = filler_img_info.iloc[:5*total_blocks]
nonrepeat_fillers = filler_img_info.iloc[5*total_blocks:].reset_index(drop=True)

# %%
repeated_fillers
# Out:
#     Unnamed: 0        Index Image type  Image index  Distinctiveness  \
# 0            0    Target-13     Target           13      1028.490965
# 1            1    Target-35     Target           35       950.452337
# 2            2    Target-47     Target           47      1054.453721
# 3            3    Target-84     Target           84       960.994005
# 4            4   Target-120     Target          120       960.948838
# ..         ...          ...        ...          ...              ...
# 60          60  Target-1649     Target         1649      1023.126735
# 61          61  Target-1688     Target         1688      1052.879704
# 62          62  Target-1715     Target         1715      1037.490198
# 63          63  Target-1720     Target         1720      1040.637973
# 64          64  Target-1769     Target         1769      1048.584329
#
#     Reconstruction error  Distinctiveness rank  RE rank
# 0               0.048492                5528.0   5595.0
# 1               0.044604                4248.0   4533.0
# 2               0.048502                5967.0   5598.0
# 3               0.045019                4425.0   4666.0
# 4               0.046065                4421.0   4929.0
# ..                   ...                   ...      ...
# 60              0.047184                5454.0   5257.0
# 61              0.049151                5939.0   5753.0
# 62              0.046154                5679.0   4956.0
# 63              0.048091                5740.0   5505.0
# 64              0.047223                5873.0   5269.0
#
# [65 rows x 8 columns]

# %%
# Sort the images into different groups
Large_RE_Small_Dist = target_img_info[(target_img_info['RE group']=='Large')&
                                     (target_img_info['Dist group']=='Small')].sort_values(by='Reconstruction error', ascending=False).reset_index(drop=True)
Large_RE_Large_Dist = target_img_info[(target_img_info['RE group']=='Large')&
                                     (target_img_info['Dist group']=='Large')].sort_values(by='Reconstruction error', ascending=False).reset_index(drop=True)
Small_RE_Small_Dist = target_img_info[(target_img_info['RE group']=='Large')&
                                     (target_img_info['Dist group']=='Small')].sort_values(by='Reconstruction error').reset_index(drop=True)
Small_RE_Large_Dist = target_img_info[(target_img_info['RE group']=='Large')&
                                     (target_img_info['Dist group']=='Large')].sort_values(by='Reconstruction error').reset_index(drop=True)

# %%
img_cond_dict = {1:Large_RE_Small_Dist,
                2:Large_RE_Large_Dist,
                3:Small_RE_Small_Dist,
                4:Small_RE_Large_Dist}

# %% [markdown]
# 1. Memorability effect is quite robust at different memory lags. Maybe let's just try to repeat the target images at lages of 20-40. We should make sure that the mean repetition lag doesn't differ across the four groups of images.
# 2. We can have filler images (i.e. those that are not part of the four groups) that repeat at a shorter timescale (1-3), as an attention check.
# 3. Because it may be tiring to do the task all in one go, we can break the task in to 4 blocks of 7 minutes each.
# Each block consists of 17 images from each of the target image group (therefore 68 in total), 5 filler images that repeat at short timescle, and 30 fller images that never repeat. This leads to a total of 176 trials each.
# 4. Following Lin et al. (2021, Cognition), each image will be presented for 1.2 s and ITI is 1.2
# Therefore, each block will last about 7 mins (422.4 seconds).
# 5. Filler images can be sampled from the filler_images dataframe, which are images with RE and Dist in the middle.
# The experiment dataframe should consist of the following columns: block number, trial number, image index, trial type (old or new), response (empty for now) and reaction time (empty for now)

# %%
def generate_trial_sequence(
    num_conditions=4,
    images_per_condition=15,
    target_repeat_lag_range=(20, 40),
    num_filler_single=20,
    num_filler_repeat=5,
    filler_repeat_lag_range=(1, 3),
    total_trials=150,
    seed=None,
    max_repeats_in_last_n=6,
    check_last_n=10
):
    if seed is not None:
        random.seed(seed)

    # 1. Generate image labels
    target_images = [
        f'T{cond}_{i}' for cond in range(1, num_conditions + 1)
        for i in range(1, images_per_condition + 1)
    ]
    filler_single = [f'F_S{i}' for i in range(1, num_filler_single + 1)]
    filler_repeat = [f'F_R{i}' for i in range(1, num_filler_repeat + 1)]

    sequence = [None] * total_trials
    used_positions = set()

    def place_with_lag(img, min_lag, max_lag, total_len):
        attempts = 0
        while attempts < 1000:
            pos1 = random.randint(0, total_len - min_lag - 1)
            lag = random.randint(min_lag, max_lag)
            pos2 = pos1 + lag
            if pos2 >= total_len:
                attempts += 1
                continue
            if pos1 not in used_positions and pos2 not in used_positions:
                return pos1, pos2
            attempts += 1
        return None, None

    # 2. Place target images
    for img in target_images:
        pos1, pos2 = place_with_lag(img, *target_repeat_lag_range, total_trials)
        if pos1 is None:
            raise RuntimeError(f"Could not place target {img}")
        sequence[pos1] = (img, False)
        sequence[pos2] = (img, True)
        used_positions.update([pos1, pos2])

    # 3. Place repeating fillers
    for img in filler_repeat:
        pos1, pos2 = place_with_lag(img, *filler_repeat_lag_range, total_trials)
        if pos1 is None:
            raise RuntimeError(f"Could not place repeating filler {img}")
        sequence[pos1] = (img, False)
        sequence[pos2] = (img, True)
        used_positions.update([pos1, pos2])

    # 4. Place non-repeating fillers
    remaining_slots = [i for i in range(total_trials) if i not in used_positions]
    if len(remaining_slots) < num_filler_single:
        raise RuntimeError("Not enough slots for single fillers")
    random.shuffle(remaining_slots)
    for i, img in enumerate(filler_single):
        pos = remaining_slots[i]
        sequence[pos] = (img, False)
        used_positions.add(pos)

    # 5. Post-hoc check: Too many repeats at the end?
    def count_repeats(trial_list, start):
        return sum(1 for t in trial_list[start:] if t and t[1] is True)

    last_n_start = total_trials - check_last_n
    repeat_count = count_repeats(sequence, last_n_start)

    if repeat_count > max_repeats_in_last_n:
        # Try to reduce by swapping
        early_idxs = [i for i in range(total_trials - check_last_n) if sequence[i] and sequence[i][1] is False]
        late_idxs = [i for i in range(last_n_start, total_trials) if sequence[i] and sequence[i][1] is True]

        swaps_done = 0
        for late_idx in late_idxs:
            for early_idx in early_idxs:
                # Swap early non-repeat with late repeat
                sequence[early_idx], sequence[late_idx] = sequence[late_idx], sequence[early_idx]
                new_repeat_count = count_repeats(sequence, last_n_start)
                if new_repeat_count <= max_repeats_in_last_n:
                    swaps_done += 1
                    break
                else:
                    # Revert and try next
                    sequence[early_idx], sequence[late_idx] = sequence[late_idx], sequence[early_idx]
            if count_repeats(sequence, last_n_start) <= max_repeats_in_last_n:
                break

        # Final check
        if count_repeats(sequence, last_n_start) > max_repeats_in_last_n:
            raise RuntimeError("Could not enforce repeat constraint in last trials")

    # 6. Format output
    final_sequence = []
    for i, trial in enumerate(sequence):
        if trial is None:
            final_sequence.append({
                'trial_num': i + 1,
                'image': None,
                'is_repeat': None,
                'type': 'EMPTY'
            })
        else:
            img, is_repeat = trial
            trial_type = 'target' if img.startswith('T') else 'filler'
            final_sequence.append({
                'trial_num': i + 1,
                'image': img,
                'is_repeat': is_repeat,
                'type': trial_type
            })

    return final_sequence

# %%
def generate_valid_sequence(max_attempts=100, verbose=True):
    for attempt in range(max_attempts):
        seed = random.randint(0, 1000000)
        try:
            sequence = generate_trial_sequence(seed=seed)
            if verbose:
                print(f"✅ Sequence generated successfully on attempt {attempt+1} (seed={seed})")
            return sequence
        except RuntimeError as e:
            if verbose:
                print(f"⚠️ Attempt {attempt+1} failed (seed={seed}): {str(e)}")
    raise RuntimeError("❌ Failed to generate a valid sequence after multiple attempts.")

# %%
for curr_block in range(total_blocks):
    # Generate trial sequence
    
    block_sequence_dict = generate_valid_sequence()
    
    # Place the images
    if curr_block != 12:
        df_t1 = img_cond_dict[1].iloc[curr_block*n_imgs_per_cond:(curr_block+1)*n_imgs_per_cond]
        df_t2 = img_cond_dict[2].iloc[curr_block*n_imgs_per_cond:(curr_block+1)*n_imgs_per_cond]
        df_t3 = img_cond_dict[3].iloc[curr_block*n_imgs_per_cond:(curr_block+1)*n_imgs_per_cond]
        df_t4 = img_cond_dict[4].iloc[curr_block*n_imgs_per_cond:(curr_block+1)*n_imgs_per_cond]
        df_f_single = nonrepeat_fillers.iloc[curr_block*20:(curr_block+1)*20]
        df_f_repeat = repeated_fillers.iloc[curr_block*5:(curr_block+1)*5]
    else:
        df_t1 = img_cond_dict[1].iloc[curr_block*n_imgs_per_cond:]
        df_t2 = img_cond_dict[2].iloc[curr_block*n_imgs_per_cond:]
        df_t3 = img_cond_dict[3].iloc[curr_block*n_imgs_per_cond:]
        df_t4 = img_cond_dict[4].iloc[curr_block*n_imgs_per_cond:]
        df_f_single = nonrepeat_fillers.iloc[curr_block*20:]
        df_f_repeat = repeated_fillers.iloc[curr_block*5:]
    
    # Step 1: Build a lookup dictionary for images
    image_lookup = {}
    # Target conditions
    for i, df in enumerate([df_t1, df_t2, df_t3, df_t4], start=1):
        for j, path in enumerate(df['Index']):
            label = f'T{i}_{j+1}'  # matches label from generate_trial_sequence
            image_lookup[label] = path

    # Fillers - single appearance
    for i, path in enumerate(df_f_single['Index'], start=1):
        label = f'F_S{i}'
        image_lookup[label] = path

    # Fillers - repeating
    for i, path in enumerate(df_f_repeat['Index'], start=1):
        label = f'F_R{i}'
        image_lookup[label] = path

    # Step 2: Assign image paths to your generated sequence

    for trial in block_sequence_dict:
        label = trial['image']
        trial['Image Index'] = image_lookup.get(label, None)
    
    block_df = pd.DataFrame(block_sequence_dict)
    block_df['Block'] = curr_block+1
# Out:
# ⚠️ Attempt 1 failed (seed=997588): Could not enforce repeat constraint in last trials
# ✅ Sequence generated successfully on attempt 2 (seed=486324)
# ✅ Sequence generated successfully on attempt 1 (seed=370839)
# ✅ Sequence generated successfully on attempt 1 (seed=130177)
# ✅ Sequence generated successfully on attempt 1 (seed=374026)
# ✅ Sequence generated successfully on attempt 1 (seed=87490)
# ✅ Sequence generated successfully on attempt 1 (seed=138823)
# ✅ Sequence generated successfully on attempt 1 (seed=139445)
# ⚠️ Attempt 1 failed (seed=736584): Could not enforce repeat constraint in last trials
# ⚠️ Attempt 2 failed (seed=400545): Could not enforce repeat constraint in last trials
# ✅ Sequence generated successfully on attempt 3 (seed=209070)
# ✅ Sequence generated successfully on attempt 1 (seed=926597)
# ✅ Sequence generated successfully on attempt 1 (seed=624854)
# ✅ Sequence generated successfully on attempt 1 (seed=922971)
# ✅ Sequence generated successfully on attempt 1 (seed=906229)
# ✅ Sequence generated successfully on attempt 1 (seed=582388)

# %%
Exp_dir = './Experiment/'
for sub in range(1, 51):
    sub_dir = os.path.join(Exp_dir, f"sub-{sub:02d}")
    if not os.path.isdir(sub_dir):
        os.mkdir(sub_dir)
    for curr_block in range(total_blocks):
        # Generate trial sequence
        block_sequence_dict = generate_valid_sequence()

        # Place the images
        if curr_block != 12:
            df_t1 = img_cond_dict[1].iloc[curr_block*n_imgs_per_cond:(curr_block+1)*n_imgs_per_cond]
            df_t2 = img_cond_dict[2].iloc[curr_block*n_imgs_per_cond:(curr_block+1)*n_imgs_per_cond]
            df_t3 = img_cond_dict[3].iloc[curr_block*n_imgs_per_cond:(curr_block+1)*n_imgs_per_cond]
            df_t4 = img_cond_dict[4].iloc[curr_block*n_imgs_per_cond:(curr_block+1)*n_imgs_per_cond]
            df_f_single = nonrepeat_fillers.iloc[curr_block*20:(curr_block+1)*20]
            df_f_repeat = repeated_fillers.iloc[curr_block*5:(curr_block+1)*5]
        else:
            df_t1 = img_cond_dict[1].iloc[curr_block*n_imgs_per_cond:]
            df_t2 = img_cond_dict[2].iloc[curr_block*n_imgs_per_cond:]
            df_t3 = img_cond_dict[3].iloc[curr_block*n_imgs_per_cond:]
            df_t4 = img_cond_dict[4].iloc[curr_block*n_imgs_per_cond:]
            df_f_single = nonrepeat_fillers.iloc[curr_block*20:]
            df_f_repeat = repeated_fillers.iloc[curr_block*5:]

        # Step 1: Build a lookup dictionary for images
        image_lookup = {}
        # Target conditions
        for i, df in enumerate([df_t1, df_t2, df_t3, df_t4], start=1):
            for j, path in enumerate(df['Index']):
                label = f'T{i}_{j+1}'  # matches label from generate_trial_sequence
                image_lookup[label] = path

        # Fillers - single appearance
        for i, path in enumerate(df_f_single['Index'], start=1):
            label = f'F_S{i}'
            image_lookup[label] = path

        # Fillers - repeating
        for i, path in enumerate(df_f_repeat['Index'], start=1):
            label = f'F_R{i}'
            image_lookup[label] = path

        # Step 2: Assign image paths to your generated sequence

        for trial in block_sequence_dict:
            label = trial['image']
            trial['Image Index'] = image_lookup.get(label, None)

        block_df = pd.DataFrame(block_sequence_dict)
        block_df['Block'] = curr_block+1
        
        block_dir = os.path.join(sub_dir, f"Block{curr_block+1:02d}_info.csv")
        block_df.to_csv(block_dir)
# Out:
# ⚠️ Attempt 1 failed (seed=7288): Could not enforce repeat constraint in last trials
# ✅ Sequence generated successfully on attempt 2 (seed=801151)
# ⚠️ Attempt 1 failed (seed=243221): Could not enforce repeat constraint in last trials
# ⚠️ Attempt 2 failed (seed=6039): Could not enforce repeat constraint in last trials
# ⚠️ Attempt 3 failed (seed=330106): Could not enforce repeat constraint in last trials
# ✅ Sequence generated successfully on attempt 4 (seed=836209)
# ✅ Sequence generated successfully on attempt 1 (seed=505077)
# ✅ Sequence generated successfully on attempt 1 (seed=573619)
# ⚠️ Attempt 1 failed (seed=377466): Could not enforce repeat constraint in last trials
# ✅ Sequence generated successfully on attempt 2 (seed=425904)
# ⚠️ Attempt 1 failed (seed=940861): Could not enforce repeat constraint in last trials
# ✅ Sequence generated successfully on attempt 2 (seed=678650)
# ⚠️ Attempt 1 failed (seed=597285): Could not enforce repeat constraint in last trials
# ✅ Sequence generated successfully on attempt 2 (seed=858109)
# ✅ Sequence generated successfully on attempt 1 (seed=747885)
# ✅ Sequence generated successfully on attempt 1 (seed=500261)
# ⚠️ Attempt 1 failed (seed=306627): Could not enforce repeat constraint in last trials
# ⚠️ Attempt 2 failed (seed=328835): Could not enforce repeat constraint in last trials
# ✅ Sequence generated successfully on attempt 3 (seed=993800)
# ✅ Sequence generated successfully on attempt 1 (seed=213729)
# ✅ Sequence generated successfully on attempt 1 (seed=328427)
# ⚠️ Attempt 1 failed (seed=162572): Could not enforce repeat constraint in last trials
# ✅ Sequence generated successfully on attempt 2 (seed=92058)
# ⚠️ Attempt 1 failed (seed=629975): Could not enforce repeat constraint in last trials
# ⚠️ Attempt 2 failed (seed=710960): Could not enforce repeat constraint in last trials
# ✅ Sequence generated successfully on attempt 3 (seed=452891)
# ✅ Sequence generated successfully on attempt 1 (seed=750726)
# ⚠️ Attempt 1 failed (seed=708257): Could not enforce repeat constraint in last trials
# ✅ Sequence generated successfully on attempt 2 (seed=399241)
# ⚠️ Attempt 1 failed (seed=584169): Could not enforce repeat constraint in last trials
# ⚠️ Attempt 2 failed (seed=181545): Could not enforce repeat constraint in last trials
# ⚠️ Attempt 3 failed (seed=892667): Could not enforce repeat constraint in last trials
# ✅ Sequence generated successfully on attempt 4 (seed=452984)
# ✅ Sequence generated successfully on attempt 1 (seed=932900)
# ✅ Sequence generated successfully on attempt 1 (seed=180648)
# ✅ Sequence generated successfully on attempt 1 (seed=549395)
# ✅ Sequence generated successfully on attempt 1 (seed=993356)
# ✅ Sequence generated successfully on attempt 1 (seed=208351)
# ⚠️ Attempt 1 failed (seed=980682): Could not enforce repeat constraint in last trials
# ✅ Sequence generated successfully on attempt 2 (seed=220784)
# ✅ Sequence generated successfully on attempt 1 (seed=117357)
# ✅ Sequence generated successfully on attempt 1 (seed=246129)
# ✅ Sequence generated successfully on attempt 1 (seed=40271)
# ✅ Sequence generated successfully on attempt 1 (seed=975232)
# ⚠️ Attempt 1 failed (seed=768278): Could not enforce repeat constraint in last trials
# ✅ Sequence generated successfully on attempt 2 (seed=741507)
# ✅ Sequence generated successfully on attempt 1 (seed=264157)
# ⚠️ Attempt 1 failed (seed=648565): Could not enforce repeat constraint in last trials
# ⚠️ Attempt 2 failed (seed=76589): Could not enforce repeat constraint in last trials
# ⚠️ Attempt 3 failed (seed=144083): Could not enforce repeat constraint in last trials
# ✅ Sequence generated successfully on attempt 4 (seed=934277)
# ⚠️ Attempt 1 failed (seed=814332): Could not enforce repeat constraint in last trials
# ✅ Sequence generated successfully on attempt 2 (seed=462739)
# ✅ Sequence generated successfully on attempt 1 (seed=123289)
# ✅ Sequence generated successfully on attempt 1 (seed=186287)
# ⚠️ Attempt 1 failed (seed=739571): Could not enforce repeat constraint in last trials
# ✅ Sequence generated successfully on attempt 2 (seed=778100)
# ⚠️ Attempt 1 failed (seed=831375): Could not enforce repeat constraint in last trials
# ⚠️ Attempt 2 failed (seed=807218): Could not enforce repeat constraint in last trials
# ⚠️ Attempt 3 failed (seed=302602): Could not enforce repeat constraint in last trials
# ⚠️ Attempt 4 failed (seed=567996): Could not enforce repeat constraint in last trials
# ✅ Sequence generated successfully on attempt 5 (seed=436405)
# ⚠️ Attempt 1 failed (seed=918131): Could not enforce repeat constraint in last trials
# ⚠️ Attempt 2 failed (seed=510123): Could not enforce repeat constraint in last trials
# ✅ Sequence generated successfully on attempt 3 (seed=712193)
# ✅ Sequence generated successfully on attempt 1 (seed=738455)
# ✅ Sequence generated successfully on attempt 1 (seed=489565)
# ✅ Sequence generated successfully on attempt 1 (seed=334980)
# ✅ Sequence generated successfully on attempt 1 (seed=677721)
# ✅ Sequence generated successfully on attempt 1 (seed=994620)
# ✅ Sequence generated successfully on attempt 1 (seed=75377)
# ✅ Sequence generated successfully on attempt 1 (seed=429642)
# ✅ Sequence generated successfully on attempt 1 (seed=511650)
# ⚠️ Attempt 1 failed (seed=346473): Could not enforce repeat constraint in last trials
# ⚠️ Attempt 2 failed (seed=977606): Could not enforce repeat constraint in last trials
# ✅ Sequence generated successfully on attempt 3 (seed=928707)
# ⚠️ Attempt 1 failed (seed=897708): Could not enforce repeat constraint in last trials
# ⚠️ Attempt 2 failed (seed=846090): Could not enforce repeat constraint in last trials
# ✅ Sequence generated successfully on attempt 3 (seed=845616)
# ✅ Sequence generated successfully on attempt 1 (seed=711397)
# ✅ Sequence generated successfully on attempt 1 (seed=314509)
# ⚠️ Attempt 1 failed (seed=410473): Could not enforce repeat constraint in last trials
# ⚠️ Attempt 2 failed (seed=274333): Could not enforce repeat constraint in last trials
# ⚠️ Attempt 3 failed (seed=153678): Could not enforce repeat constraint in last trials
# ✅ Sequence generated successfully on attempt 4 (seed=826387)
# ⚠️ Attempt 1 failed (seed=676811): Could not enforce repeat constraint in last trials
# ⚠️ Attempt 2 failed (seed=104559): Could not enforce repeat constraint in last trials
# ⚠️ Attempt 3 failed (seed=812875): Could not enforce repeat constraint in last trials
# ⚠️ Attempt 4 failed (seed=1031): Could not enforce repeat constraint in last trials
# ⚠️ Attempt 5 failed (seed=942805): Could not enforce repeat constraint in last trials
# ⚠️ Attempt 6 failed (seed=473022): Could not enforce repeat constraint in last trials
# ✅ Sequence generated successfully on attempt 7 (seed=929841)
# ✅ Sequence generated successfully on attempt 1 (seed=543270)
# ✅ Sequence generated successfully on attempt 1 (seed=554089)
# ✅ Sequence generated successfully on attempt 1 (seed=512648)
# ✅ Sequence generated successfully on attempt 1 (seed=737199)
# ⚠️ Attempt 1 failed (seed=710673): Could not enforce repeat constraint in last trials
# ✅ Sequence generated successfully on attempt 2 (seed=373666)
# ✅ Sequence generated successfully on attempt 1 (seed=384439)
# ✅ Sequence generated successfully on attempt 1 (seed=401662)
# ✅ Sequence generated successfully on attempt 1 (seed=826219)
# ✅ Sequence generated successfully on attempt 1 (seed=2203)
# ✅ Sequence generated successfully on attempt 1 (seed=818310)
# ⚠️ Attempt 1 failed (seed=901586): Could not enforce repeat constraint in last trials
# ⚠️ Attempt 2 failed (seed=874786): Could not enforce repeat constraint in last trials
# ✅ Sequence generated successfully on attempt 3 (seed=203607)
# ⚠️ Attempt 1 failed (seed=260336): Could not enforce repeat constraint in last trials
# ✅ Sequence generated successfully on attempt 2 (seed=333716)
# ⚠️ Attempt 1 failed (seed=577220): Could not enforce repeat constraint in last trials
# ✅ Sequence generated successfully on attempt 2 (seed=578432)
# ⚠️ Attempt 1 failed (seed=511655): Could not enforce repeat constraint in last trials
# ✅ Sequence generated successfully on attempt 2 (seed=542835)
# ✅ Sequence generated successfully on attempt 1 (seed=235107)
# ⚠️ Attempt 1 failed (seed=110723): Could not enforce repeat constraint in last trials
# ⚠️ Attempt 2 failed (seed=231298): Could not enforce repeat constraint in last trials
# ✅ Sequence generated successfully on attempt 3 (seed=736263)
# ✅ Sequence generated successfully on attempt 1 (seed=436015)
# ✅ Sequence generated successfully on attempt 1 (seed=38083)
# ✅ Sequence generated successfully on attempt 1 (seed=649493)
# ⚠️ Attempt 1 failed (seed=943441): Could not enforce repeat constraint in last trials
# ⚠️ Attempt 2 failed (seed=269526): Could not enforce repeat constraint in last trials
# ⚠️ Attempt 3 failed (seed=286113): Could not enforce repeat constraint in last trials
# ✅ Sequence generated successfully on attempt 4 (seed=623708)
# ⚠️ Attempt 1 failed (seed=546791): Could not enforce repeat constraint in last trials
# ⚠️ Attempt 2 failed (seed=751146): Could not enforce repeat constraint in last trials
# ✅ Sequence generated successfully on attempt 3 (seed=655800)
# ⚠️ Attempt 1 failed (seed=145421): Could not enforce repeat constraint in last trials
# ⚠️ Attempt 2 failed (seed=655196): Could not enforce repeat constraint in last trials
# ⚠️ Attempt 3 failed (seed=368888): Could not enforce repeat constraint in last trials
# ⚠️ Attempt 4 failed (seed=984464): Could not enforce repeat constraint in last trials
# ⚠️ Attempt 5 failed (seed=138366): Could not enforce repeat constraint in last trials
# ⚠️ Attempt 6 failed (seed=511784): Could not enforce repeat constraint in last trials
# ⚠️ Attempt 7 failed (seed=340617): Could not enforce repeat constraint in last trials
# ⚠️ Attempt 8 failed (seed=317476): Could not enforce repeat constraint in last trials
# ✅ Sequence generated successfully on attempt 9 (seed=322594)
# ✅ Sequence generated successfully on attempt 1 (seed=238143)
# ⚠️ Attempt 1 failed (seed=854192): Could not enforce repeat constraint in last trials
# ✅ Sequence generated successfully on attempt 2 (seed=944537)
# ⚠️ Attempt 1 failed (seed=112887): Could not enforce repeat constraint in last trials
# ✅ Sequence generated successfully on attempt 2 (seed=204431)
# ✅ Sequence generated successfully on attempt 1 (seed=786056)
# ✅ Sequence generated successfully on attempt 1 (seed=876891)
# ⚠️ Attempt 1 failed (seed=642683): Could not enforce repeat constraint in last trials
# ✅ Sequence generated successfully on attempt 2 (seed=227879)
# ✅ Sequence generated successfully on attempt 1 (seed=278058)
# ✅ Sequence generated successfully on attempt 1 (seed=778650)
# ✅ Sequence generated successfully on attempt 1 (seed=996545)
# ✅ Sequence generated successfully on attempt 1 (seed=605887)
# ✅ Sequence generated successfully on attempt 1 (seed=473845)
# ⚠️ Attempt 1 failed (seed=45343): Could not enforce repeat constraint in last trials
# ⚠️ Attempt 2 failed (seed=744112): Could not enforce repeat constraint in last trials
# ✅ Sequence generated successfully on attempt 3 (seed=147455)
# ⚠️ Attempt 1 failed (seed=534477): Could not enforce repeat constraint in last trials
# ✅ Sequence generated successfully on attempt 2 (seed=980719)
# ⚠️ Attempt 1 failed (seed=142829): Could not enforce repeat constraint in last trials
# ✅ Sequence generated successfully on attempt 2 (seed=328492)
# ⚠️ Attempt 1 failed (seed=893562): Could not enforce repeat constraint in last trials
# ⚠️ Attempt 2 failed (seed=282004): Could not enforce repeat constraint in last trials
# ⚠️ Attempt 3 failed (seed=224089): Could not enforce repeat constraint in last trials
# ✅ Sequence generated successfully on attempt 4 (seed=895595)
# ✅ Sequence generated successfully on attempt 1 (seed=346736)
# ⚠️ Attempt 1 failed (seed=422794): Could not enforce repeat constraint in last trials
# ⚠️ Attempt 2 failed (seed=483216): Could not enforce repeat constraint in last trials
# ⚠️ Attempt 3 failed (seed=864507): Could not enforce repeat constraint in last trials
# ⚠️ Attempt 4 failed (seed=711139): Could not enforce repeat constraint in last trials
# ✅ Sequence generated successfully on attempt 5 (seed=791383)
# ✅ Sequence generated successfully on attempt 1 (seed=490506)
# ✅ Sequence generated successfully on attempt 1 (seed=303308)
# ⚠️ Attempt 1 failed (seed=139717): Could not enforce repeat constraint in last trials
# ⚠️ Attempt 2 failed (seed=853971): Could not enforce repeat constraint in last trials
# ✅ Sequence generated successfully on attempt 3 (seed=97019)
# ✅ Sequence generated successfully on attempt 1 (seed=21052)
# ✅ Sequence generated successfully on attempt 1 (seed=984295)
# ✅ Sequence generated successfully on attempt 1 (seed=931496)
# ⚠️ Attempt 1 failed (seed=466187): Could not enforce repeat constraint in last trials
# ✅ Sequence generated successfully on attempt 2 (seed=557683)
# ✅ Sequence generated successfully on attempt 1 (seed=35935)
# ✅ Sequence generated successfully on attempt 1 (seed=291756)
# ⚠️ Attempt 1 failed (seed=834907): Could not enforce repeat constraint in last trials
# ✅ Sequence generated successfully on attempt 2 (seed=73332)
# ✅ Sequence generated successfully on attempt 1 (seed=434669)
# ✅ Sequence generated successfully on attempt 1 (seed=912155)
# ⚠️ Attempt 1 failed (seed=741702): Could not enforce repeat constraint in last trials
# ✅ Sequence generated successfully on attempt 2 (seed=288284)
# ✅ Sequence generated successfully on attempt 1 (seed=987456)
# ⚠️ Attempt 1 failed (seed=916425): Could not enforce repeat constraint in last trials
# ✅ Sequence generated successfully on attempt 2 (seed=710278)
# ✅ Sequence generated successfully on attempt 1 (seed=543297)
# ✅ Sequence generated successfully on attempt 1 (seed=966160)
# ⚠️ Attempt 1 failed (seed=320287): Could not enforce repeat constraint in last trials
# ✅ Sequence generated successfully on attempt 2 (seed=456201)
# ✅ Sequence generated successfully on attempt 1 (seed=763587)
# ✅ Sequence generated successfully on attempt 1 (seed=711757)
# ⚠️ Attempt 1 failed (seed=447599): Could not enforce repeat constraint in last trials
# ⚠️ Attempt 2 failed (seed=487805): Could not enforce repeat constraint in last trials
# ⚠️ Attempt 3 failed (seed=735108): Could not enforce repeat constraint in last trials
# ⚠️ Attempt 4 failed (seed=241504): Could not enforce repeat constraint in last trials
# ⚠️ Attempt 5 failed (seed=759843): Could not enforce repeat constraint in last trials
# ⚠️ Attempt 6 failed (seed=634466): Could not enforce repeat constraint in last trials
# ✅ Sequence generated successfully on attempt 7 (seed=716353)
# ✅ Sequence generated successfully on attempt 1 (seed=847777)
# ⚠️ Attempt 1 failed (seed=919060): Could not enforce repeat constraint in last trials
# ✅ Sequence generated successfully on attempt 2 (seed=914905)
# ✅ Sequence generated successfully on attempt 1 (seed=342499)
# ✅ Sequence generated successfully on attempt 1 (seed=316645)
# ⚠️ Attempt 1 failed (seed=602819): Could not enforce repeat constraint in last trials
# ✅ Sequence generated successfully on attempt 2 (seed=115024)
# ⚠️ Attempt 1 failed (seed=737591): Could not enforce repeat constraint in last trials
# ✅ Sequence generated successfully on attempt 2 (seed=730020)
# ✅ Sequence generated successfully on attempt 1 (seed=93463)
# ✅ Sequence generated successfully on attempt 1 (seed=733623)
# ⚠️ Attempt 1 failed (seed=915884): Could not enforce repeat constraint in last trials
# ✅ Sequence generated successfully on attempt 2 (seed=703072)
# ⚠️ Attempt 1 failed (seed=778331): Could not enforce repeat constraint in last trials
# ✅ Sequence generated successfully on attempt 2 (seed=795112)
# ✅ Sequence generated successfully on attempt 1 (seed=700728)
# ⚠️ Attempt 1 failed (seed=337868): Could not enforce repeat constraint in last trials
# ✅ Sequence generated successfully on attempt 2 (seed=961873)
# ✅ Sequence generated successfully on attempt 1 (seed=922522)
# ✅ Sequence generated successfully on attempt 1 (seed=779277)
# ✅ Sequence generated successfully on attempt 1 (seed=273330)
# ⚠️ Attempt 1 failed (seed=821218): Could not enforce repeat constraint in last trials
# ⚠️ Attempt 2 failed (seed=691422): Could not enforce repeat constraint in last trials
# ✅ Sequence generated successfully on attempt 3 (seed=121737)
# ✅ Sequence generated successfully on attempt 1 (seed=688276)
# ✅ Sequence generated successfully on attempt 1 (seed=68459)
# ⚠️ Attempt 1 failed (seed=455276): Could not enforce repeat constraint in last trials
# ⚠️ Attempt 2 failed (seed=221071): Could not enforce repeat constraint in last trials
# ✅ Sequence generated successfully on attempt 3 (seed=543371)
# ✅ Sequence generated successfully on attempt 1 (seed=496544)
# ⚠️ Attempt 1 failed (seed=403539): Could not enforce repeat constraint in last trials
# ⚠️ Attempt 2 failed (seed=256527): Could not enforce repeat constraint in last trials
# ✅ Sequence generated successfully on attempt 3 (seed=459048)
# ✅ Sequence generated successfully on attempt 1 (seed=6811)
# ⚠️ Attempt 1 failed (seed=410277): Could not enforce repeat constraint in last trials
# ✅ Sequence generated successfully on attempt 2 (seed=351634)
# ✅ Sequence generated successfully on attempt 1 (seed=218537)
# ✅ Sequence generated successfully on attempt 1 (seed=124868)
# ⚠️ Attempt 1 failed (seed=370659): Could not enforce repeat constraint in last trials
# ⚠️ Attempt 2 failed (seed=857771): Could not enforce repeat constraint in last trials
# ✅ Sequence generated successfully on attempt 3 (seed=255912)
# ✅ Sequence generated successfully on attempt 1 (seed=732534)
# ✅ Sequence generated successfully on attempt 1 (seed=713)
# ⚠️ Attempt 1 failed (seed=479941): Could not enforce repeat constraint in last trials
# ⚠️ Attempt 2 failed (seed=986293): Could not enforce repeat constraint in last trials
# ⚠️ Attempt 3 failed (seed=706324): Could not enforce repeat constraint in last trials
# ✅ Sequence generated successfully on attempt 4 (seed=461559)
# ⚠️ Attempt 1 failed (seed=310050): Could not enforce repeat constraint in last trials
# ⚠️ Attempt 2 failed (seed=948445): Could not enforce repeat constraint in last trials
# ⚠️ Attempt 3 failed (seed=7285): Could not enforce repeat constraint in last trials
# ✅ Sequence generated successfully on attempt 4 (seed=983826)
# ✅ Sequence generated successfully on attempt 1 (seed=142337)
# ⚠️ Attempt 1 failed (seed=260864): Could not enforce repeat constraint in last trials
# ✅ Sequence generated successfully on attempt 2 (seed=717282)
# ⚠️ Attempt 1 failed (seed=802283): Could not enforce repeat constraint in last trials
# ⚠️ Attempt 2 failed (seed=976975): Could not enforce repeat constraint in last trials
# ✅ Sequence generated successfully on attempt 3 (seed=828796)
# ✅ Sequence generated successfully on attempt 1 (seed=173787)
# ⚠️ Attempt 1 failed (seed=622571): Could not enforce repeat constraint in last trials
# ⚠️ Attempt 2 failed (seed=842110): Could not enforce repeat constraint in last trials
# ⚠️ Attempt 3 failed (seed=367435): Could not enforce repeat constraint in last trials
# ⚠️ Attempt 4 failed (seed=323142): Could not enforce repeat constraint in last trials
# ⚠️ Attempt 5 failed (seed=643919): Could not enforce repeat constraint in last trials
# ✅ Sequence generated successfully on attempt 6 (seed=258057)
# ⚠️ Attempt 1 failed (seed=156184): Could not enforce repeat constraint in last trials
# ✅ Sequence generated successfully on attempt 2 (seed=108045)
# ⚠️ Attempt 1 failed (seed=927337): Could not enforce repeat constraint in last trials
# ⚠️ Attempt 2 failed (seed=491821): Could not enforce repeat constraint in last trials
# ✅ Sequence generated successfully on attempt 3 (seed=271750)
# ✅ Sequence generated successfully on attempt 1 (seed=317301)
# ✅ Sequence generated successfully on attempt 1 (seed=985746)
# ⚠️ Attempt 1 failed (seed=569901): Could not enforce repeat constraint in last trials
# ✅ Sequence generated successfully on attempt 2 (seed=246416)
# ✅ Sequence generated successfully on attempt 1 (seed=267282)
# ⚠️ Attempt 1 failed (seed=667886): Could not enforce repeat constraint in last trials
# ⚠️ Attempt 2 failed (seed=169893): Could not enforce repeat constraint in last trials
# ⚠️ Attempt 3 failed (seed=453176): Could not enforce repeat constraint in last trials
# ⚠️ Attempt 4 failed (seed=530262): Could not enforce repeat constraint in last trials
# ✅ Sequence generated successfully on attempt 5 (seed=637236)
# ⚠️ Attempt 1 failed (seed=526052): Could not enforce repeat constraint in last trials
# ⚠️ Attempt 2 failed (seed=202197): Could not enforce repeat constraint in last trials
# ⚠️ Attempt 3 failed (seed=610183): Could not enforce repeat constraint in last trials
# ⚠️ Attempt 4 failed (seed=683496): Could not enforce repeat constraint in last trials
# ✅ Sequence generated successfully on attempt 5 (seed=835900)
# ⚠️ Attempt 1 failed (seed=326421): Could not enforce repeat constraint in last trials
# ⚠️ Attempt 2 failed (seed=998794): Could not enforce repeat constraint in last trials
# ⚠️ Attempt 3 failed (seed=621341): Could not enforce repeat constraint in last trials
# ✅ Sequence generated successfully on attempt 4 (seed=631535)
# ⚠️ Attempt 1 failed (seed=483325): Could not enforce repeat constraint in last trials
# ⚠️ Attempt 2 failed (seed=359229): Could not enforce repeat constraint in last trials
# ✅ Sequence generated successfully on attempt 3 (seed=249057)
# ⚠️ Attempt 1 failed (seed=896346): Could not enforce repeat constraint in last trials
# ✅ Sequence generated successfully on attempt 2 (seed=148645)
# ⚠️ Attempt 1 failed (seed=614904): Could not enforce repeat constraint in last trials
# ⚠️ Attempt 2 failed (seed=506327): Could not enforce repeat constraint in last trials
# ⚠️ Attempt 3 failed (seed=460374): Could not enforce repeat constraint in last trials
# ✅ Sequence generated successfully on attempt 4 (seed=92629)
# ⚠️ Attempt 1 failed (seed=762598): Could not enforce repeat constraint in last trials
# ✅ Sequence generated successfully on attempt 2 (seed=450629)
# ✅ Sequence generated successfully on attempt 1 (seed=73522)
# ⚠️ Attempt 1 failed (seed=776258): Could not enforce repeat constraint in last trials
# ✅ Sequence generated successfully on attempt 2 (seed=117728)
# ⚠️ Attempt 1 failed (seed=709521): Could not enforce repeat constraint in last trials
# ✅ Sequence generated successfully on attempt 2 (seed=351743)
# ✅ Sequence generated successfully on attempt 1 (seed=697270)
# ✅ Sequence generated successfully on attempt 1 (seed=910755)
# ✅ Sequence generated successfully on attempt 1 (seed=130504)
# ⚠️ Attempt 1 failed (seed=30335): Could not enforce repeat constraint in last trials
# ⚠️ Attempt 2 failed (seed=305288): Could not enforce repeat constraint in last trials
# ⚠️ Attempt 3 failed (seed=915996): Could not enforce repeat constraint in last trials
# ✅ Sequence generated successfully on attempt 4 (seed=994285)
# ⚠️ Attempt 1 failed (seed=397730): Could not enforce repeat constraint in last trials
# ⚠️ Attempt 2 failed (seed=525674): Could not enforce repeat constraint in last trials
# ✅ Sequence generated successfully on attempt 3 (seed=555366)
# ⚠️ Attempt 1 failed (seed=359335): Could not enforce repeat constraint in last trials
# ✅ Sequence generated successfully on attempt 2 (seed=153560)
# ✅ Sequence generated successfully on attempt 1 (seed=494651)
# ✅ Sequence generated successfully on attempt 1 (seed=954757)
# ✅ Sequence generated successfully on attempt 1 (seed=291910)
# ✅ Sequence generated successfully on attempt 1 (seed=988070)
# ✅ Sequence generated successfully on attempt 1 (seed=149031)
# ✅ Sequence generated successfully on attempt 1 (seed=436063)
# ✅ Sequence generated successfully on attempt 1 (seed=735927)
# ⚠️ Attempt 1 failed (seed=238483): Could not enforce repeat constraint in last trials
# ⚠️ Attempt 2 failed (seed=523639): Could not enforce repeat constraint in last trials
# ✅ Sequence generated successfully on attempt 3 (seed=671675)
# ⚠️ Attempt 1 failed (seed=70323): Could not enforce repeat constraint in last trials
# ⚠️ Attempt 2 failed (seed=222034): Could not enforce repeat constraint in last trials
# ⚠️ Attempt 3 failed (seed=410342): Could not enforce repeat constraint in last trials
# ⚠️ Attempt 4 failed (seed=387797): Could not enforce repeat constraint in last trials
# ✅ Sequence generated successfully on attempt 5 (seed=17230)
# ⚠️ Attempt 1 failed (seed=662338): Could not enforce repeat constraint in last trials
# ⚠️ Attempt 2 failed (seed=115394): Could not enforce repeat constraint in last trials
# ⚠️ Attempt 3 failed (seed=734160): Could not enforce repeat constraint in last trials
# ⚠️ Attempt 4 failed (seed=966843): Could not enforce repeat constraint in last trials
# ✅ Sequence generated successfully on attempt 5 (seed=315180)
# ✅ Sequence generated successfully on attempt 1 (seed=44247)
# ⚠️ Attempt 1 failed (seed=712693): Could not enforce repeat constraint in last trials
# ⚠️ Attempt 2 failed (seed=278048): Could not enforce repeat constraint in last trials
# ✅ Sequence generated successfully on attempt 3 (seed=996983)
# ✅ Sequence generated successfully on attempt 1 (seed=222208)
# ⚠️ Attempt 1 failed (seed=341623): Could not enforce repeat constraint in last trials
# ⚠️ Attempt 2 failed (seed=536901): Could not enforce repeat constraint in last trials
# ⚠️ Attempt 3 failed (seed=860933): Could not enforce repeat constraint in last trials
# ⚠️ Attempt 4 failed (seed=966932): Could not enforce repeat constraint in last trials
# ✅ Sequence generated successfully on attempt 5 (seed=526046)
# ⚠️ Attempt 1 failed (seed=583566): Could not enforce repeat constraint in last trials
# ⚠️ Attempt 2 failed (seed=139920): Could not enforce repeat constraint in last trials
# ⚠️ Attempt 3 failed (seed=980336): Could not enforce repeat constraint in last trials
# ⚠️ Attempt 4 failed (seed=813006): Could not enforce repeat constraint in last trials
# ⚠️ Attempt 5 failed (seed=950822): Could not enforce repeat constraint in last trials
# ⚠️ Attempt 6 failed (seed=539465): Could not enforce repeat constraint in last trials
# ⚠️ Attempt 7 failed (seed=774783): Could not enforce repeat constraint in last trials
# ✅ Sequence generated successfully on attempt 8 (seed=817502)
# ⚠️ Attempt 1 failed (seed=181995): Could not enforce repeat constraint in last trials
# ✅ Sequence generated successfully on attempt 2 (seed=848685)
# ✅ Sequence generated successfully on attempt 1 (seed=119696)
# ⚠️ Attempt 1 failed (seed=59317): Could not enforce repeat constraint in last trials
# ⚠️ Attempt 2 failed (seed=412274): Could not enforce repeat constraint in last trials
# ✅ Sequence generated successfully on attempt 3 (seed=804561)
# ⚠️ Attempt 1 failed (seed=610345): Could not enforce repeat constraint in last trials
# ⚠️ Attempt 2 failed (seed=354376): Could not enforce repeat constraint in last trials
# ⚠️ Attempt 3 failed (seed=720689): Could not enforce repeat constraint in last trials
# ⚠️ Attempt 4 failed (seed=142486): Could not enforce repeat constraint in last trials
# ✅ Sequence generated successfully on attempt 5 (seed=104008)
# ⚠️ Attempt 1 failed (seed=535025): Could not enforce repeat constraint in last trials
# ✅ Sequence generated successfully on attempt 2 (seed=343054)
# ⚠️ Attempt 1 failed (seed=407708): Could not enforce repeat constraint in last trials
# ⚠️ Attempt 2 failed (seed=575796): Could not enforce repeat constraint in last trials
# ⚠️ Attempt 3 failed (seed=224272): Could not enforce repeat constraint in last trials
# ✅ Sequence generated successfully on attempt 4 (seed=286206)
# ⚠️ Attempt 1 failed (seed=546448): Could not enforce repeat constraint in last trials
# ✅ Sequence generated successfully on attempt 2 (seed=148163)
# ✅ Sequence generated successfully on attempt 1 (seed=393091)
# ⚠️ Attempt 1 failed (seed=499226): Could not enforce repeat constraint in last trials
# ✅ Sequence generated successfully on attempt 2 (seed=206410)
# ✅ Sequence generated successfully on attempt 1 (seed=914030)
# ✅ Sequence generated successfully on attempt 1 (seed=239781)
# ⚠️ Attempt 1 failed (seed=670818): Could not enforce repeat constraint in last trials
# ✅ Sequence generated successfully on attempt 2 (seed=582839)
# ⚠️ Attempt 1 failed (seed=378248): Could not enforce repeat constraint in last trials
# ⚠️ Attempt 2 failed (seed=296366): Could not enforce repeat constraint in last trials
# ✅ Sequence generated successfully on attempt 3 (seed=464534)
# ⚠️ Attempt 1 failed (seed=588237): Could not enforce repeat constraint in last trials
# ⚠️ Attempt 2 failed (seed=271478): Could not enforce repeat constraint in last trials
# ⚠️ Attempt 3 failed (seed=872418): Could not enforce repeat constraint in last trials
# ✅ Sequence generated successfully on attempt 4 (seed=396761)
# ✅ Sequence generated successfully on attempt 1 (seed=690133)
# ⚠️ Attempt 1 failed (seed=507546): Could not enforce repeat constraint in last trials
# ✅ Sequence generated successfully on attempt 2 (seed=20817)
# ⚠️ Attempt 1 failed (seed=238497): Could not enforce repeat constraint in last trials
# ⚠️ Attempt 2 failed (seed=165640): Could not enforce repeat constraint in last trials
# ⚠️ Attempt 3 failed (seed=770793): Could not enforce repeat constraint in last trials
# ⚠️ Attempt 4 failed (seed=389825): Could not enforce repeat constraint in last trials
# ✅ Sequence generated successfully on attempt 5 (seed=781822)
# ✅ Sequence generated successfully on attempt 1 (seed=846739)
# ⚠️ Attempt 1 failed (seed=211438): Could not enforce repeat constraint in last trials
# ✅ Sequence generated successfully on attempt 2 (seed=923386)
# ⚠️ Attempt 1 failed (seed=965887): Could not enforce repeat constraint in last trials
# ✅ Sequence generated successfully on attempt 2 (seed=950762)
# ⚠️ Attempt 1 failed (seed=700667): Could not enforce repeat constraint in last trials
# ✅ Sequence generated successfully on attempt 2 (seed=337978)
# ⚠️ Attempt 1 failed (seed=381660): Could not enforce repeat constraint in last trials
# ✅ Sequence generated successfully on attempt 2 (seed=126668)
# ⚠️ Attempt 1 failed (seed=112837): Could not enforce repeat constraint in last trials
# ⚠️ Attempt 2 failed (seed=438190): Could not enforce repeat constraint in last trials
# ⚠️ Attempt 3 failed (seed=240368): Could not enforce repeat constraint in last trials
# ✅ Sequence generated successfully on attempt 4 (seed=743638)
# ✅ Sequence generated successfully on attempt 1 (seed=750780)
# ✅ Sequence generated successfully on attempt 1 (seed=252963)
# ✅ Sequence generated successfully on attempt 1 (seed=268894)
# ⚠️ Attempt 1 failed (seed=75605): Could not enforce repeat constraint in last trials
# ⚠️ Attempt 2 failed (seed=343684): Could not enforce repeat constraint in last trials
# ⚠️ Attempt 3 failed (seed=610263): Could not enforce repeat constraint in last trials
# ✅ Sequence generated successfully on attempt 4 (seed=574021)
# ⚠️ Attempt 1 failed (seed=502402): Could not enforce repeat constraint in last trials
# ✅ Sequence generated successfully on attempt 2 (seed=832811)
# ⚠️ Attempt 1 failed (seed=629609): Could not enforce repeat constraint in last trials
# ✅ Sequence generated successfully on attempt 2 (seed=999018)
# ✅ Sequence generated successfully on attempt 1 (seed=876280)
# ✅ Sequence generated successfully on attempt 1 (seed=237490)
# ⚠️ Attempt 1 failed (seed=812922): Could not enforce repeat constraint in last trials
# ⚠️ Attempt 2 failed (seed=383143): Could not enforce repeat constraint in last trials
# ✅ Sequence generated successfully on attempt 3 (seed=162318)
# ⚠️ Attempt 1 failed (seed=380735): Could not enforce repeat constraint in last trials
# ✅ Sequence generated successfully on attempt 2 (seed=801293)
# ⚠️ Attempt 1 failed (seed=906223): Could not enforce repeat constraint in last trials
# ✅ Sequence generated successfully on attempt 2 (seed=882394)
# ⚠️ Attempt 1 failed (seed=95448): Could not enforce repeat constraint in last trials
# ⚠️ Attempt 2 failed (seed=149739): Could not enforce repeat constraint in last trials
# ✅ Sequence generated successfully on attempt 3 (seed=230044)
# ✅ Sequence generated successfully on attempt 1 (seed=397733)
# ✅ Sequence generated successfully on attempt 1 (seed=56206)
# ⚠️ Attempt 1 failed (seed=834248): Could not enforce repeat constraint in last trials
# ⚠️ Attempt 2 failed (seed=861205): Could not enforce repeat constraint in last trials
# ⚠️ Attempt 3 failed (seed=988267): Could not enforce repeat constraint in last trials
# ✅ Sequence generated successfully on attempt 4 (seed=116535)
# ✅ Sequence generated successfully on attempt 1 (seed=855267)
# ✅ Sequence generated successfully on attempt 1 (seed=173539)
# ✅ Sequence generated successfully on attempt 1 (seed=987688)
# ⚠️ Attempt 1 failed (seed=571005): Could not enforce repeat constraint in last trials
# ✅ Sequence generated successfully on attempt 2 (seed=952299)
# ✅ Sequence generated successfully on attempt 1 (seed=886607)
# ⚠️ Attempt 1 failed (seed=471828): Could not enforce repeat constraint in last trials
# ⚠️ Attempt 2 failed (seed=222547): Could not enforce repeat constraint in last trials
# ✅ Sequence generated successfully on attempt 3 (seed=791916)
# ⚠️ Attempt 1 failed (seed=662564): Could not enforce repeat constraint in last trials
# ⚠️ Attempt 2 failed (seed=107303): Could not enforce repeat constraint in last trials
# ✅ Sequence generated successfully on attempt 3 (seed=520215)
# ⚠️ Attempt 1 failed (seed=113773): Could not enforce repeat constraint in last trials
# ✅ Sequence generated successfully on attempt 2 (seed=247933)
# ⚠️ Attempt 1 failed (seed=630602): Could not enforce repeat constraint in last trials
# ✅ Sequence generated successfully on attempt 2 (seed=12760)
# ✅ Sequence generated successfully on attempt 1 (seed=736401)
# ✅ Sequence generated successfully on attempt 1 (seed=13259)
# ✅ Sequence generated successfully on attempt 1 (seed=866615)
# ✅ Sequence generated successfully on attempt 1 (seed=240086)
# ⚠️ Attempt 1 failed (seed=453698): Could not enforce repeat constraint in last trials
# ✅ Sequence generated successfully on attempt 2 (seed=980000)
# ⚠️ Attempt 1 failed (seed=890317): Could not enforce repeat constraint in last trials
# ✅ Sequence generated successfully on attempt 2 (seed=37180)
# ✅ Sequence generated successfully on attempt 1 (seed=2159)
# ✅ Sequence generated successfully on attempt 1 (seed=763201)
# ✅ Sequence generated successfully on attempt 1 (seed=870137)
# ✅ Sequence generated successfully on attempt 1 (seed=35077)
# ✅ Sequence generated successfully on attempt 1 (seed=597832)
# ✅ Sequence generated successfully on attempt 1 (seed=478732)
# ⚠️ Attempt 1 failed (seed=68675): Could not enforce repeat constraint in last trials
# ⚠️ Attempt 2 failed (seed=793725): Could not enforce repeat constraint in last trials
# ✅ Sequence generated successfully on attempt 3 (seed=514647)
# ✅ Sequence generated successfully on attempt 1 (seed=454036)
# ⚠️ Attempt 1 failed (seed=546289): Could not enforce repeat constraint in last trials
# ⚠️ Attempt 2 failed (seed=109784): Could not enforce repeat constraint in last trials
# ⚠️ Attempt 3 failed (seed=585975): Could not enforce repeat constraint in last trials
# ⚠️ Attempt 4 failed (seed=37113): Could not enforce repeat constraint in last trials
# ⚠️ Attempt 5 failed (seed=315695): Could not enforce repeat constraint in last trials
# ✅ Sequence generated successfully on attempt 6 (seed=686754)
# ✅ Sequence generated successfully on attempt 1 (seed=37515)
# ⚠️ Attempt 1 failed (seed=768774): Could not enforce repeat constraint in last trials
# ✅ Sequence generated successfully on attempt 2 (seed=138638)
# ⚠️ Attempt 1 failed (seed=823240): Could not enforce repeat constraint in last trials
# ⚠️ Attempt 2 failed (seed=503080): Could not enforce repeat constraint in last trials
# ✅ Sequence generated successfully on attempt 3 (seed=276201)
# ⚠️ Attempt 1 failed (seed=222286): Could not enforce repeat constraint in last trials
# ✅ Sequence generated successfully on attempt 2 (seed=637479)
# ✅ Sequence generated successfully on attempt 1 (seed=881940)
# ✅ Sequence generated successfully on attempt 1 (seed=346281)
# ✅ Sequence generated successfully on attempt 1 (seed=923050)
# ✅ Sequence generated successfully on attempt 1 (seed=981229)
# ⚠️ Attempt 1 failed (seed=973471): Could not enforce repeat constraint in last trials
# ✅ Sequence generated successfully on attempt 2 (seed=121725)
# ✅ Sequence generated successfully on attempt 1 (seed=546416)
# ⚠️ Attempt 1 failed (seed=98154): Could not enforce repeat constraint in last trials
# ✅ Sequence generated successfully on attempt 2 (seed=303871)
# ✅ Sequence generated successfully on attempt 1 (seed=807094)
# ✅ Sequence generated successfully on attempt 1 (seed=106208)
# ✅ Sequence generated successfully on attempt 1 (seed=60129)
# ⚠️ Attempt 1 failed (seed=768676): Could not enforce repeat constraint in last trials
# ✅ Sequence generated successfully on attempt 2 (seed=238788)
# ✅ Sequence generated successfully on attempt 1 (seed=737292)
# ✅ Sequence generated successfully on attempt 1 (seed=284785)
# ✅ Sequence generated successfully on attempt 1 (seed=811695)
# ⚠️ Attempt 1 failed (seed=618530): Could not enforce repeat constraint in last trials
# ✅ Sequence generated successfully on attempt 2 (seed=171798)
# ⚠️ Attempt 1 failed (seed=305288): Could not enforce repeat constraint in last trials
# ⚠️ Attempt 2 failed (seed=915996): Could not enforce repeat constraint in last trials
# ✅ Sequence generated successfully on attempt 3 (seed=994285)
# ⚠️ Attempt 1 failed (seed=397730): Could not enforce repeat constraint in last trials
# ⚠️ Attempt 2 failed (seed=525674): Could not enforce repeat constraint in last trials
# ✅ Sequence generated successfully on attempt 3 (seed=555366)
# ⚠️ Attempt 1 failed (seed=359335): Could not enforce repeat constraint in last trials
# ✅ Sequence generated successfully on attempt 2 (seed=153560)
# ✅ Sequence generated successfully on attempt 1 (seed=494651)
# ✅ Sequence generated successfully on attempt 1 (seed=954757)
# ✅ Sequence generated successfully on attempt 1 (seed=291910)
# ✅ Sequence generated successfully on attempt 1 (seed=988070)
# ✅ Sequence generated successfully on attempt 1 (seed=149031)
# ✅ Sequence generated successfully on attempt 1 (seed=436063)
# ✅ Sequence generated successfully on attempt 1 (seed=735927)
# ⚠️ Attempt 1 failed (seed=238483): Could not enforce repeat constraint in last trials
# ⚠️ Attempt 2 failed (seed=523639): Could not enforce repeat constraint in last trials
# ✅ Sequence generated successfully on attempt 3 (seed=671675)
# ⚠️ Attempt 1 failed (seed=70323): Could not enforce repeat constraint in last trials
# ⚠️ Attempt 2 failed (seed=222034): Could not enforce repeat constraint in last trials
# ⚠️ Attempt 3 failed (seed=410342): Could not enforce repeat constraint in last trials
# ⚠️ Attempt 4 failed (seed=387797): Could not enforce repeat constraint in last trials
# ✅ Sequence generated successfully on attempt 5 (seed=17230)
# ⚠️ Attempt 1 failed (seed=662338): Could not enforce repeat constraint in last trials
# ⚠️ Attempt 2 failed (seed=115394): Could not enforce repeat constraint in last trials
# ⚠️ Attempt 3 failed (seed=734160): Could not enforce repeat constraint in last trials
# ⚠️ Attempt 4 failed (seed=966843): Could not enforce repeat constraint in last trials
# ✅ Sequence generated successfully on attempt 5 (seed=315180)
# ✅ Sequence generated successfully on attempt 1 (seed=44247)
# ⚠️ Attempt 1 failed (seed=712693): Could not enforce repeat constraint in last trials
# ⚠️ Attempt 2 failed (seed=278048): Could not enforce repeat constraint in last trials
# ✅ Sequence generated successfully on attempt 3 (seed=996983)
# ✅ Sequence generated successfully on attempt 1 (seed=222208)
# ⚠️ Attempt 1 failed (seed=341623): Could not enforce repeat constraint in last trials
# ⚠️ Attempt 2 failed (seed=536901): Could not enforce repeat constraint in last trials
# ⚠️ Attempt 3 failed (seed=860933): Could not enforce repeat constraint in last trials
# ⚠️ Attempt 4 failed (seed=966932): Could not enforce repeat constraint in last trials
# ✅ Sequence generated successfully on attempt 5 (seed=526046)
# ⚠️ Attempt 1 failed (seed=583566): Could not enforce repeat constraint in last trials
# ⚠️ Attempt 2 failed (seed=139920): Could not enforce repeat constraint in last trials
# ⚠️ Attempt 3 failed (seed=980336): Could not enforce repeat constraint in last trials
# ⚠️ Attempt 4 failed (seed=813006): Could not enforce repeat constraint in last trials
# ⚠️ Attempt 5 failed (seed=950822): Could not enforce repeat constraint in last trials
# ⚠️ Attempt 6 failed (seed=539465): Could not enforce repeat constraint in last trials
# ⚠️ Attempt 7 failed (seed=774783): Could not enforce repeat constraint in last trials
# ✅ Sequence generated successfully on attempt 8 (seed=817502)
# ⚠️ Attempt 1 failed (seed=181995): Could not enforce repeat constraint in last trials
# ✅ Sequence generated successfully on attempt 2 (seed=848685)
# ✅ Sequence generated successfully on attempt 1 (seed=119696)
# ⚠️ Attempt 1 failed (seed=59317): Could not enforce repeat constraint in last trials
# ⚠️ Attempt 2 failed (seed=412274): Could not enforce repeat constraint in last trials
# ✅ Sequence generated successfully on attempt 3 (seed=804561)
# ⚠️ Attempt 1 failed (seed=610345): Could not enforce repeat constraint in last trials
# ⚠️ Attempt 2 failed (seed=354376): Could not enforce repeat constraint in last trials
# ⚠️ Attempt 3 failed (seed=720689): Could not enforce repeat constraint in last trials
# ⚠️ Attempt 4 failed (seed=142486): Could not enforce repeat constraint in last trials
# ✅ Sequence generated successfully on attempt 5 (seed=104008)
# ⚠️ Attempt 1 failed (seed=535025): Could not enforce repeat constraint in last trials
# ✅ Sequence generated successfully on attempt 2 (seed=343054)
# ⚠️ Attempt 1 failed (seed=407708): Could not enforce repeat constraint in last trials
# ⚠️ Attempt 2 failed (seed=575796): Could not enforce repeat constraint in last trials
# ⚠️ Attempt 3 failed (seed=224272): Could not enforce repeat constraint in last trials
# ✅ Sequence generated successfully on attempt 4 (seed=286206)
# ⚠️ Attempt 1 failed (seed=546448): Could not enforce repeat constraint in last trials
# ✅ Sequence generated successfully on attempt 2 (seed=148163)
# ✅ Sequence generated successfully on attempt 1 (seed=393091)
# ⚠️ Attempt 1 failed (seed=499226): Could not enforce repeat constraint in last trials
# ✅ Sequence generated successfully on attempt 2 (seed=206410)
# ✅ Sequence generated successfully on attempt 1 (seed=914030)
# ✅ Sequence generated successfully on attempt 1 (seed=239781)
# ⚠️ Attempt 1 failed (seed=670818): Could not enforce repeat constraint in last trials
# ✅ Sequence generated successfully on attempt 2 (seed=582839)
# ⚠️ Attempt 1 failed (seed=378248): Could not enforce repeat constraint in last trials
# ⚠️ Attempt 2 failed (seed=296366): Could not enforce repeat constraint in last trials
# ✅ Sequence generated successfully on attempt 3 (seed=464534)
# ⚠️ Attempt 1 failed (seed=588237): Could not enforce repeat constraint in last trials
# ⚠️ Attempt 2 failed (seed=271478): Could not enforce repeat constraint in last trials
# ⚠️ Attempt 3 failed (seed=872418): Could not enforce repeat constraint in last trials
# ✅ Sequence generated successfully on attempt 4 (seed=396761)
# ✅ Sequence generated successfully on attempt 1 (seed=690133)
# ⚠️ Attempt 1 failed (seed=507546): Could not enforce repeat constraint in last trials
# ✅ Sequence generated successfully on attempt 2 (seed=20817)
# ⚠️ Attempt 1 failed (seed=238497): Could not enforce repeat constraint in last trials
# ⚠️ Attempt 2 failed (seed=165640): Could not enforce repeat constraint in last trials
# ⚠️ Attempt 3 failed (seed=770793): Could not enforce repeat constraint in last trials
# ⚠️ Attempt 4 failed (seed=389825): Could not enforce repeat constraint in last trials
# ✅ Sequence generated successfully on attempt 5 (seed=781822)
# ✅ Sequence generated successfully on attempt 1 (seed=846739)
# ⚠️ Attempt 1 failed (seed=211438): Could not enforce repeat constraint in last trials
# ✅ Sequence generated successfully on attempt 2 (seed=923386)
# ⚠️ Attempt 1 failed (seed=965887): Could not enforce repeat constraint in last trials
# ✅ Sequence generated successfully on attempt 2 (seed=950762)
# ⚠️ Attempt 1 failed (seed=700667): Could not enforce repeat constraint in last trials
# ✅ Sequence generated successfully on attempt 2 (seed=337978)
# ⚠️ Attempt 1 failed (seed=381660): Could not enforce repeat constraint in last trials
# ✅ Sequence generated successfully on attempt 2 (seed=126668)
# ⚠️ Attempt 1 failed (seed=112837): Could not enforce repeat constraint in last trials
# ⚠️ Attempt 2 failed (seed=438190): Could not enforce repeat constraint in last trials
# ⚠️ Attempt 3 failed (seed=240368): Could not enforce repeat constraint in last trials
# ✅ Sequence generated successfully on attempt 4 (seed=743638)
# ✅ Sequence generated successfully on attempt 1 (seed=750780)
# ✅ Sequence generated successfully on attempt 1 (seed=252963)
# ✅ Sequence generated successfully on attempt 1 (seed=268894)
# ⚠️ Attempt 1 failed (seed=75605): Could not enforce repeat constraint in last trials
# ⚠️ Attempt 2 failed (seed=343684): Could not enforce repeat constraint in last trials
# ⚠️ Attempt 3 failed (seed=610263): Could not enforce repeat constraint in last trials
# ✅ Sequence generated successfully on attempt 4 (seed=574021)
# ⚠️ Attempt 1 failed (seed=502402): Could not enforce repeat constraint in last trials
# ✅ Sequence generated successfully on attempt 2 (seed=832811)
# ⚠️ Attempt 1 failed (seed=629609): Could not enforce repeat constraint in last trials
# ✅ Sequence generated successfully on attempt 2 (seed=999018)
# ✅ Sequence generated successfully on attempt 1 (seed=876280)
# ✅ Sequence generated successfully on attempt 1 (seed=237490)
# ⚠️ Attempt 1 failed (seed=812922): Could not enforce repeat constraint in last trials
# ⚠️ Attempt 2 failed (seed=383143): Could not enforce repeat constraint in last trials
# ✅ Sequence generated successfully on attempt 3 (seed=162318)
# ⚠️ Attempt 1 failed (seed=380735): Could not enforce repeat constraint in last trials
# ✅ Sequence generated successfully on attempt 2 (seed=801293)
# ⚠️ Attempt 1 failed (seed=906223): Could not enforce repeat constraint in last trials
# ✅ Sequence generated successfully on attempt 2 (seed=882394)
# ⚠️ Attempt 1 failed (seed=95448): Could not enforce repeat constraint in last trials
# ⚠️ Attempt 2 failed (seed=149739): Could not enforce repeat constraint in last trials
# ✅ Sequence generated successfully on attempt 3 (seed=230044)
# ✅ Sequence generated successfully on attempt 1 (seed=397733)
# ✅ Sequence generated successfully on attempt 1 (seed=56206)
# ⚠️ Attempt 1 failed (seed=834248): Could not enforce repeat constraint in last trials
# ⚠️ Attempt 2 failed (seed=861205): Could not enforce repeat constraint in last trials
# ⚠️ Attempt 3 failed (seed=988267): Could not enforce repeat constraint in last trials
# ✅ Sequence generated successfully on attempt 4 (seed=116535)
# ✅ Sequence generated successfully on attempt 1 (seed=855267)
# ✅ Sequence generated successfully on attempt 1 (seed=173539)
# ✅ Sequence generated successfully on attempt 1 (seed=987688)
# ⚠️ Attempt 1 failed (seed=571005): Could not enforce repeat constraint in last trials
# ✅ Sequence generated successfully on attempt 2 (seed=952299)
# ✅ Sequence generated successfully on attempt 1 (seed=886607)
# ⚠️ Attempt 1 failed (seed=471828): Could not enforce repeat constraint in last trials
# ⚠️ Attempt 2 failed (seed=222547): Could not enforce repeat constraint in last trials
# ✅ Sequence generated successfully on attempt 3 (seed=791916)
# ⚠️ Attempt 1 failed (seed=662564): Could not enforce repeat constraint in last trials
# ⚠️ Attempt 2 failed (seed=107303): Could not enforce repeat constraint in last trials
# ✅ Sequence generated successfully on attempt 3 (seed=520215)
# ⚠️ Attempt 1 failed (seed=113773): Could not enforce repeat constraint in last trials
# ✅ Sequence generated successfully on attempt 2 (seed=247933)
# ⚠️ Attempt 1 failed (seed=630602): Could not enforce repeat constraint in last trials
# ✅ Sequence generated successfully on attempt 2 (seed=12760)
# ✅ Sequence generated successfully on attempt 1 (seed=736401)
# ✅ Sequence generated successfully on attempt 1 (seed=13259)
# ✅ Sequence generated successfully on attempt 1 (seed=866615)
# ✅ Sequence generated successfully on attempt 1 (seed=240086)
# ⚠️ Attempt 1 failed (seed=453698): Could not enforce repeat constraint in last trials
# ✅ Sequence generated successfully on attempt 2 (seed=980000)
# ...
# ✅ Sequence generated successfully on attempt 1 (seed=454036)
# ⚠️ Attempt 1 failed (seed=546289): Could not enforce repeat constraint in last trials
# ⚠️ Attempt 2 failed (seed=109784): Could not enforce repeat constraint in last trials
# ⚠️ Attempt 3 failed (seed=585975): Could not enforce repeat constraint in last trials
# ⚠️ Attempt 4 failed (seed=37113): Could not enforce repeat constraint in last trials
# ⚠️ Attempt 5 failed (seed=315695): Could not enforce repeat constraint in last trials
# ✅ Sequence generated successfully on attempt 6 (seed=686754)
# ✅ Sequence generated successfully on attempt 1 (seed=37515)
# ⚠️ Attempt 1 failed (seed=768774): Could not enforce repeat constraint in last trials
# ✅ Sequence generated successfully on attempt 2 (seed=138638)
# ⚠️ Attempt 1 failed (seed=823240): Could not enforce repeat constraint in last trials
# ⚠️ Attempt 2 failed (seed=503080): Could not enforce repeat constraint in last trials
# ✅ Sequence generated successfully on attempt 3 (seed=276201)
# ⚠️ Attempt 1 failed (seed=222286): Could not enforce repeat constraint in last trials
# ✅ Sequence generated successfully on attempt 2 (seed=637479)
# ✅ Sequence generated successfully on attempt 1 (seed=881940)
# ✅ Sequence generated successfully on attempt 1 (seed=346281)
# ✅ Sequence generated successfully on attempt 1 (seed=923050)
# ✅ Sequence generated successfully on attempt 1 (seed=981229)
# ⚠️ Attempt 1 failed (seed=973471): Could not enforce repeat constraint in last trials
# ✅ Sequence generated successfully on attempt 2 (seed=121725)
# ✅ Sequence generated successfully on attempt 1 (seed=546416)
# ⚠️ Attempt 1 failed (seed=98154): Could not enforce repeat constraint in last trials
# ✅ Sequence generated successfully on attempt 2 (seed=303871)
# ✅ Sequence generated successfully on attempt 1 (seed=807094)
# ✅ Sequence generated successfully on attempt 1 (seed=106208)
# ✅ Sequence generated successfully on attempt 1 (seed=60129)
# ⚠️ Attempt 1 failed (seed=768676): Could not enforce repeat constraint in last trials
# ✅ Sequence generated successfully on attempt 2 (seed=238788)
# ✅ Sequence generated successfully on attempt 1 (seed=737292)
# ✅ Sequence generated successfully on attempt 1 (seed=284785)
# ✅ Sequence generated successfully on attempt 1 (seed=811695)
# ⚠️ Attempt 1 failed (seed=618530): Could not enforce repeat constraint in last trials
# ✅ Sequence generated successfully on attempt 2 (seed=171798)
# ⚠️ Attempt 1 failed (seed=305288): Could not enforce repeat constraint in last trials
# ⚠️ Attempt 2 failed (seed=915996): Could not enforce repeat constraint in last trials
# ✅ Sequence generated successfully on attempt 3 (seed=994285)
# ⚠️ Attempt 1 failed (seed=397730): Could not enforce repeat constraint in last trials
# ⚠️ Attempt 2 failed (seed=525674): Could not enforce repeat constraint in last trials
# ✅ Sequence generated successfully on attempt 3 (seed=555366)
# ⚠️ Attempt 1 failed (seed=359335): Could not enforce repeat constraint in last trials
# ✅ Sequence generated successfully on attempt 2 (seed=153560)
# ✅ Sequence generated successfully on attempt 1 (seed=494651)
# ✅ Sequence generated successfully on attempt 1 (seed=954757)
# ✅ Sequence generated successfully on attempt 1 (seed=291910)
# ✅ Sequence generated successfully on attempt 1 (seed=988070)
# ✅ Sequence generated successfully on attempt 1 (seed=149031)
# ✅ Sequence generated successfully on attempt 1 (seed=436063)
# ✅ Sequence generated successfully on attempt 1 (seed=735927)
# ⚠️ Attempt 1 failed (seed=238483): Could not enforce repeat constraint in last trials
# ⚠️ Attempt 2 failed (seed=523639): Could not enforce repeat constraint in last trials
# ✅ Sequence generated successfully on attempt 3 (seed=671675)
# ⚠️ Attempt 1 failed (seed=70323): Could not enforce repeat constraint in last trials
# ⚠️ Attempt 2 failed (seed=222034): Could not enforce repeat constraint in last trials
# ⚠️ Attempt 3 failed (seed=410342): Could not enforce repeat constraint in last trials
# ⚠️ Attempt 4 failed (seed=387797): Could not enforce repeat constraint in last trials
# ✅ Sequence generated successfully on attempt 5 (seed=17230)
# ⚠️ Attempt 1 failed (seed=662338): Could not enforce repeat constraint in last trials
# ⚠️ Attempt 2 failed (seed=115394): Could not enforce repeat constraint in last trials
# ⚠️ Attempt 3 failed (seed=734160): Could not enforce repeat constraint in last trials
# ⚠️ Attempt 4 failed (seed=966843): Could not enforce repeat constraint in last trials
# ✅ Sequence generated successfully on attempt 5 (seed=315180)
# ✅ Sequence generated successfully on attempt 1 (seed=44247)
# ⚠️ Attempt 1 failed (seed=712693): Could not enforce repeat constraint in last trials
# ⚠️ Attempt 2 failed (seed=278048): Could not enforce repeat constraint in last trials
# ✅ Sequence generated successfully on attempt 3 (seed=996983)
# ✅ Sequence generated successfully on attempt 1 (seed=222208)
# ⚠️ Attempt 1 failed (seed=341623): Could not enforce repeat constraint in last trials
# ⚠️ Attempt 2 failed (seed=536901): Could not enforce repeat constraint in last trials
# ⚠️ Attempt 3 failed (seed=860933): Could not enforce repeat constraint in last trials
# ⚠️ Attempt 4 failed (seed=966932): Could not enforce repeat constraint in last trials
# ✅ Sequence generated successfully on attempt 5 (seed=526046)
# ⚠️ Attempt 1 failed (seed=583566): Could not enforce repeat constraint in last trials
# ⚠️ Attempt 2 failed (seed=139920): Could not enforce repeat constraint in last trials
# ⚠️ Attempt 3 failed (seed=980336): Could not enforce repeat constraint in last trials
# ⚠️ Attempt 4 failed (seed=813006): Could not enforce repeat constraint in last trials
# ⚠️ Attempt 5 failed (seed=950822): Could not enforce repeat constraint in last trials
# ⚠️ Attempt 6 failed (seed=539465): Could not enforce repeat constraint in last trials
# ⚠️ Attempt 7 failed (seed=774783): Could not enforce repeat constraint in last trials
# ✅ Sequence generated successfully on attempt 8 (seed=817502)
# ⚠️ Attempt 1 failed (seed=181995): Could not enforce repeat constraint in last trials
# ✅ Sequence generated successfully on attempt 2 (seed=848685)
# ✅ Sequence generated successfully on attempt 1 (seed=119696)
# ⚠️ Attempt 1 failed (seed=59317): Could not enforce repeat constraint in last trials
# ⚠️ Attempt 2 failed (seed=412274): Could not enforce repeat constraint in last trials
# ✅ Sequence generated successfully on attempt 3 (seed=804561)
# ⚠️ Attempt 1 failed (seed=610345): Could not enforce repeat constraint in last trials
# ⚠️ Attempt 2 failed (seed=354376): Could not enforce repeat constraint in last trials
# ⚠️ Attempt 3 failed (seed=720689): Could not enforce repeat constraint in last trials
# ⚠️ Attempt 4 failed (seed=142486): Could not enforce repeat constraint in last trials
# ✅ Sequence generated successfully on attempt 5 (seed=104008)
# ⚠️ Attempt 1 failed (seed=535025): Could not enforce repeat constraint in last trials
# ✅ Sequence generated successfully on attempt 2 (seed=343054)
# ⚠️ Attempt 1 failed (seed=407708): Could not enforce repeat constraint in last trials
# ⚠️ Attempt 2 failed (seed=575796): Could not enforce repeat constraint in last trials
# ⚠️ Attempt 3 failed (seed=224272): Could not enforce repeat constraint in last trials
# ✅ Sequence generated successfully on attempt 4 (seed=286206)
# ⚠️ Attempt 1 failed (seed=546448): Could not enforce repeat constraint in last trials
# ✅ Sequence generated successfully on attempt 2 (seed=148163)
# ✅ Sequence generated successfully on attempt 1 (seed=393091)
# ⚠️ Attempt 1 failed (seed=499226): Could not enforce repeat constraint in last trials
# ✅ Sequence generated successfully on attempt 2 (seed=206410)
# ✅ Sequence generated successfully on attempt 1 (seed=914030)
# ✅ Sequence generated successfully on attempt 1 (seed=239781)
# ⚠️ Attempt 1 failed (seed=670818): Could not enforce repeat constraint in last trials
# ✅ Sequence generated successfully on attempt 2 (seed=582839)
# ⚠️ Attempt 1 failed (seed=378248): Could not enforce repeat constraint in last trials
# ⚠️ Attempt 2 failed (seed=296366): Could not enforce repeat constraint in last trials
# ✅ Sequence generated successfully on attempt 3 (seed=464534)
# ⚠️ Attempt 1 failed (seed=588237): Could not enforce repeat constraint in last trials
# ⚠️ Attempt 2 failed (seed=271478): Could not enforce repeat constraint in last trials
# ⚠️ Attempt 3 failed (seed=872418): Could not enforce repeat constraint in last trials
# ✅ Sequence generated successfully on attempt 4 (seed=396761)
# ✅ Sequence generated successfully on attempt 1 (seed=690133)
# ⚠️ Attempt 1 failed (seed=507546): Could not enforce repeat constraint in last trials
# ✅ Sequence generated successfully on attempt 2 (seed=20817)
# ⚠️ Attempt 1 failed (seed=238497): Could not enforce repeat constraint in last trials
# ⚠️ Attempt 2 failed (seed=165640): Could not enforce repeat constraint in last trials
# ⚠️ Attempt 3 failed (seed=770793): Could not enforce repeat constraint in last trials
# ⚠️ Attempt 4 failed (seed=389825): Could not enforce repeat constraint in last trials
# ✅ Sequence generated successfully on attempt 5 (seed=781822)
# ✅ Sequence generated successfully on attempt 1 (seed=846739)
# ⚠️ Attempt 1 failed (seed=211438): Could not enforce repeat constraint in last trials
# ✅ Sequence generated successfully on attempt 2 (seed=923386)
# ⚠️ Attempt 1 failed (seed=965887): Could not enforce repeat constraint in last trials
# ✅ Sequence generated successfully on attempt 2 (seed=950762)
# ⚠️ Attempt 1 failed (seed=700667): Could not enforce repeat constraint in last trials
# ✅ Sequence generated successfully on attempt 2 (seed=337978)
# ⚠️ Attempt 1 failed (seed=381660): Could not enforce repeat constraint in last trials
# ✅ Sequence generated successfully on attempt 2 (seed=126668)
# ⚠️ Attempt 1 failed (seed=112837): Could not enforce repeat constraint in last trials
# ⚠️ Attempt 2 failed (seed=438190): Could not enforce repeat constraint in last trials
# ⚠️ Attempt 3 failed (seed=240368): Could not enforce repeat constraint in last trials
# ✅ Sequence generated successfully on attempt 4 (seed=743638)
# ✅ Sequence generated successfully on attempt 1 (seed=750780)
# ✅ Sequence generated successfully on attempt 1 (seed=252963)
# ✅ Sequence generated successfully on attempt 1 (seed=268894)
# ⚠️ Attempt 1 failed (seed=75605): Could not enforce repeat constraint in last trials
# ⚠️ Attempt 2 failed (seed=343684): Could not enforce repeat constraint in last trials
# ⚠️ Attempt 3 failed (seed=610263): Could not enforce repeat constraint in last trials
# ✅ Sequence generated successfully on attempt 4 (seed=574021)
# ⚠️ Attempt 1 failed (seed=502402): Could not enforce repeat constraint in last trials
# ✅ Sequence generated successfully on attempt 2 (seed=832811)
# ⚠️ Attempt 1 failed (seed=629609): Could not enforce repeat constraint in last trials
# ✅ Sequence generated successfully on attempt 2 (seed=999018)
# ✅ Sequence generated successfully on attempt 1 (seed=876280)
# ✅ Sequence generated successfully on attempt 1 (seed=237490)
# ⚠️ Attempt 1 failed (seed=812922): Could not enforce repeat constraint in last trials
# ⚠️ Attempt 2 failed (seed=383143): Could not enforce repeat constraint in last trials
# ✅ Sequence generated successfully on attempt 3 (seed=162318)
# ⚠️ Attempt 1 failed (seed=380735): Could not enforce repeat constraint in last trials
# ✅ Sequence generated successfully on attempt 2 (seed=801293)
# ⚠️ Attempt 1 failed (seed=906223): Could not enforce repeat constraint in last trials
# ✅ Sequence generated successfully on attempt 2 (seed=882394)
# ⚠️ Attempt 1 failed (seed=95448): Could not enforce repeat constraint in last trials
# ⚠️ Attempt 2 failed (seed=149739): Could not enforce repeat constraint in last trials
# ✅ Sequence generated successfully on attempt 3 (seed=230044)
# ✅ Sequence generated successfully on attempt 1 (seed=397733)
# ✅ Sequence generated successfully on attempt 1 (seed=56206)
# ⚠️ Attempt 1 failed (seed=834248): Could not enforce repeat constraint in last trials
# ⚠️ Attempt 2 failed (seed=861205): Could not enforce repeat constraint in last trials
# ⚠️ Attempt 3 failed (seed=988267): Could not enforce repeat constraint in last trials
# ✅ Sequence generated successfully on attempt 4 (seed=116535)
# ✅ Sequence generated successfully on attempt 1 (seed=855267)
# ✅ Sequence generated successfully on attempt 1 (seed=173539)
# ✅ Sequence generated successfully on attempt 1 (seed=987688)
# ⚠️ Attempt 1 failed (seed=571005): Could not enforce repeat constraint in last trials
# ✅ Sequence generated successfully on attempt 2 (seed=952299)
# ✅ Sequence generated successfully on attempt 1 (seed=886607)
# ⚠️ Attempt 1 failed (seed=471828): Could not enforce repeat constraint in last trials
# ⚠️ Attempt 2 failed (seed=222547): Could not enforce repeat constraint in last trials
# ✅ Sequence generated successfully on attempt 3 (seed=791916)
# ⚠️ Attempt 1 failed (seed=662564): Could not enforce repeat constraint in last trials
# ⚠️ Attempt 2 failed (seed=107303): Could not enforce repeat constraint in last trials
# ✅ Sequence generated successfully on attempt 3 (seed=520215)
# ⚠️ Attempt 1 failed (seed=113773): Could not enforce repeat constraint in last trials
# ✅ Sequence generated successfully on attempt 2 (seed=247933)
# ⚠️ Attempt 1 failed (seed=630602): Could not enforce repeat constraint in last trials
# ✅ Sequence generated successfully on attempt 2 (seed=12760)
# ✅ Sequence generated successfully on attempt 1 (seed=736401)
# ✅ Sequence generated successfully on attempt 1 (seed=13259)
# ✅ Sequence generated successfully on attempt 1 (seed=866615)
# ✅ Sequence generated successfully on attempt 1 (seed=240086)
# ⚠️ Attempt 1 failed (seed=453698): Could not enforce repeat constraint in last trials
# ✅ Sequence generated successfully on attempt 2 (seed=980000)
# ⚠️ Attempt 1 failed (seed=890317): Could not enforce repeat constraint in last trials
# ✅ Sequence generated successfully on attempt 2 (seed=37180)
# ✅ Sequence generated successfully on attempt 1 (seed=2159)
# ✅ Sequence generated successfully on attempt 1 (seed=763201)
# ✅ Sequence generated successfully on attempt 1 (seed=870137)
# ✅ Sequence generated successfully on attempt 1 (seed=35077)
# ✅ Sequence generated successfully on attempt 1 (seed=597832)
# ✅ Sequence generated successfully on attempt 1 (seed=478732)
# ⚠️ Attempt 1 failed (seed=68675): Could not enforce repeat constraint in last trials
# ⚠️ Attempt 2 failed (seed=793725): Could not enforce repeat constraint in last trials
# ✅ Sequence generated successfully on attempt 3 (seed=514647)
# ✅ Sequence generated successfully on attempt 1 (seed=454036)
# ⚠️ Attempt 1 failed (seed=546289): Could not enforce repeat constraint in last trials
# ⚠️ Attempt 2 failed (seed=109784): Could not enforce repeat constraint in last trials
# ⚠️ Attempt 3 failed (seed=585975): Could not enforce repeat constraint in last trials
# ⚠️ Attempt 4 failed (seed=37113): Could not enforce repeat constraint in last trials
# ⚠️ Attempt 5 failed (seed=315695): Could not enforce repeat constraint in last trials
# ✅ Sequence generated successfully on attempt 6 (seed=686754)
# ✅ Sequence generated successfully on attempt 1 (seed=37515)
# ⚠️ Attempt 1 failed (seed=768774): Could not enforce repeat constraint in last trials
# ✅ Sequence generated successfully on attempt 2 (seed=138638)
# ⚠️ Attempt 1 failed (seed=823240): Could not enforce repeat constraint in last trials
# ⚠️ Attempt 2 failed (seed=503080): Could not enforce repeat constraint in last trials
# ✅ Sequence generated successfully on attempt 3 (seed=276201)
# ⚠️ Attempt 1 failed (seed=222286): Could not enforce repeat constraint in last trials
# ✅ Sequence generated successfully on attempt 2 (seed=637479)
# ✅ Sequence generated successfully on attempt 1 (seed=881940)
# ✅ Sequence generated successfully on attempt 1 (seed=346281)
# ✅ Sequence generated successfully on attempt 1 (seed=923050)
# ✅ Sequence generated successfully on attempt 1 (seed=981229)
# ⚠️ Attempt 1 failed (seed=973471): Could not enforce repeat constraint in last trials
# ✅ Sequence generated successfully on attempt 2 (seed=121725)
# ✅ Sequence generated successfully on attempt 1 (seed=546416)

# %%
sub_dir
# Out:
# './Experiment/sub-50'

# %%
block1_sequence_df['Image placeholder index'] = [int(k.split('_')[1]) if k[0]=='T' else int(k[3:]) for k in block1_sequence_df['image']]

# %%
df_t1 = img_cond_dict[1].iloc[:n_imgs_per_cond]
df_t2 = img_cond_dict[2].iloc[:n_imgs_per_cond]
df_t3 = img_cond_dict[3].iloc[:n_imgs_per_cond]
df_t4 = img_cond_dict[4].iloc[:n_imgs_per_cond]
df_f_single = nonrepeat_fillers.iloc[:20]
df_f_repeat = repeated_fillers.iloc[:5]

# %%
# Step 1: Build a lookup dictionary for images

image_lookup = {}
# Target conditions
for i, df in enumerate([df_t1, df_t2, df_t3, df_t4], start=1):
    for j, path in enumerate(df['Index']):
        label = f'T{i}_{j+1}'  # matches label from generate_trial_sequence
        image_lookup[label] = path

# Fillers - single appearance
for i, path in enumerate(df_f_single['Index'], start=1):
    label = f'F_S{i}'
    image_lookup[label] = path

# Fillers - repeating
for i, path in enumerate(df_f_repeat['Index'], start=1):
    label = f'F_R{i}'
    image_lookup[label] = path

# Step 2: Assign image paths to your generated sequence

# Let's say you already called:
# sequence = generate_trial_sequence(seed=42)

for trial in block1_sequence_dict:
    label = trial['image']
    trial['Image Index'] = image_lookup.get(label, None)

# %%
block1_sequence_dict
# Out:
# [{'trial_num': 1,
#   'image': 'T2_6',
#   'is_repeat': True,
#   'type': 'target',
#   'Image Index': 'Filler-2883'},
#  {'trial_num': 2,
#   'image': 'T4_1',
#   'is_repeat': False,
#   'type': 'target',
#   'Image Index': 'Filler-5957'},
#  {'trial_num': 3,
#   'image': 'T1_6',
#   'is_repeat': False,
#   'type': 'target',
#   'Image Index': 'Filler-6863'},
#  {'trial_num': 4,
#   'image': 'F_R3',
#   'is_repeat': False,
#   'type': 'filler',
#   'Image Index': 'Target-47'},
#  {'trial_num': 5,
#   'image': 'T1_1',
#   'is_repeat': False,
#   'type': 'target',
#   'Image Index': 'Filler-6188'},
#  {'trial_num': 6,
#   'image': 'T2_3',
#   'is_repeat': False,
#   'type': 'target',
#   'Image Index': 'Filler-5531'},
#  {'trial_num': 7,
#   'image': 'F_R3',
#   'is_repeat': True,
#   'type': 'filler',
#   'Image Index': 'Target-47'},
#  {'trial_num': 8,
#   'image': 'F_R4',
#   'is_repeat': False,
#   'type': 'filler',
#   'Image Index': 'Target-84'},
#  {'trial_num': 9,
#   'image': 'T4_2',
#   'is_repeat': False,
#   'type': 'target',
#   'Image Index': 'Filler-2138'},
#  {'trial_num': 10,
#   'image': 'F_R4',
#   'is_repeat': True,
#   'type': 'filler',
#   'Image Index': 'Target-84'},
#  {'trial_num': 11,
#   'image': 'F_S1',
#   'is_repeat': False,
#   'type': 'filler',
#   'Image Index': 'Target-1834'},
#  {'trial_num': 12,
#   'image': 'T4_9',
#   'is_repeat': False,
#   'type': 'target',
#   'Image Index': 'Filler-6110'},
#  {'trial_num': 13,
#   'image': 'F_S20',
#   'is_repeat': False,
#   'type': 'filler',
#   'Image Index': 'Target-2203'},
#  {'trial_num': 14,
#   'image': 'T4_13',
#   'is_repeat': False,
#   'type': 'target',
#   'Image Index': 'Filler-3170'},
#  {'trial_num': 15,
#   'image': 'T1_15',
#   'is_repeat': False,
#   'type': 'target',
#   'Image Index': 'Filler-4621'},
#  {'trial_num': 16,
#   'image': 'T3_12',
#   'is_repeat': False,
#   'type': 'target',
#   'Image Index': 'Filler-68'},
#  {'trial_num': 17,
#   'image': 'T3_4',
#   'is_repeat': False,
#   'type': 'target',
#   'Image Index': 'Filler-7648'},
#  {'trial_num': 18,
#   'image': 'F_S9',
#   'is_repeat': False,
#   'type': 'filler',
#   'Image Index': 'Target-2027'},
#  {'trial_num': 19,
#   'image': 'T2_11',
#   'is_repeat': False,
#   'type': 'target',
#   'Image Index': 'Target-100'},
#  {'trial_num': 20,
#   'image': 'T1_10',
#   'is_repeat': False,
#   'type': 'target',
#   'Image Index': 'Filler-903'},
#  {'trial_num': 21,
#   'image': 'T2_10',
#   'is_repeat': False,
#   'type': 'target',
#   'Image Index': 'Filler-366'},
#  {'trial_num': 22,
#   'image': 'T3_9',
#   'is_repeat': False,
#   'type': 'target',
#   'Image Index': 'Filler-7963'},
#  {'trial_num': 23,
#   'image': 'T1_5',
#   'is_repeat': False,
#   'type': 'target',
#   'Image Index': 'Filler-4507'},
#  {'trial_num': 24,
#   'image': 'T4_15',
#   'is_repeat': True,
#   'type': 'target',
#   'Image Index': 'Filler-7486'},
#  {'trial_num': 25,
#   'image': 'T2_12',
#   'is_repeat': False,
#   'type': 'target',
#   'Image Index': 'Filler-7840'},
#  {'trial_num': 26,
#   'image': 'T2_3',
#   'is_repeat': True,
#   'type': 'target',
#   'Image Index': 'Filler-5531'},
#  {'trial_num': 27,
#   'image': 'T4_5',
#   'is_repeat': False,
#   'type': 'target',
#   'Image Index': 'Target-673'},
#  {'trial_num': 28,
#   'image': 'F_S3',
#   'is_repeat': False,
#   'type': 'filler',
#   'Image Index': 'Target-1861'},
#  {'trial_num': 29,
#   'image': 'T1_14',
#   'is_repeat': False,
#   'type': 'target',
#   'Image Index': 'Filler-2584'},
#  {'trial_num': 30,
#   'image': 'T2_4',
#   'is_repeat': False,
#   'type': 'target',
#   'Image Index': 'Filler-5605'},
#  {'trial_num': 31,
#   'image': 'T2_5',
#   'is_repeat': False,
#   'type': 'target',
#   'Image Index': 'Filler-511'},
#  {'trial_num': 32,
#   'image': 'T4_1',
#   'is_repeat': True,
#   'type': 'target',
#   'Image Index': 'Filler-5957'},
#  {'trial_num': 33,
#   'image': 'T4_2',
#   'is_repeat': True,
#   'type': 'target',
#   'Image Index': 'Filler-2138'},
#  {'trial_num': 34,
#   'image': 'T4_12',
#   'is_repeat': False,
#   'type': 'target',
#   'Image Index': 'Target-675'},
#  {'trial_num': 35,
#   'image': 'T4_9',
#   'is_repeat': True,
#   'type': 'target',
#   'Image Index': 'Filler-6110'},
#  {'trial_num': 36,
#   'image': 'T1_15',
#   'is_repeat': True,
#   'type': 'target',
#   'Image Index': 'Filler-4621'},
#  {'trial_num': 37,
#   'image': 'T3_12',
#   'is_repeat': True,
#   'type': 'target',
#   'Image Index': 'Filler-68'},
#  {'trial_num': 38,
#   'image': 'T1_6',
#   'is_repeat': True,
#   'type': 'target',
#   'Image Index': 'Filler-6863'},
#  {'trial_num': 39,
#   'image': 'T4_13',
#   'is_repeat': True,
#   'type': 'target',
#   'Image Index': 'Filler-3170'},
#  {'trial_num': 40,
#   'image': 'T3_4',
#   'is_repeat': True,
#   'type': 'target',
#   'Image Index': 'Filler-7648'},
#  {'trial_num': 41,
#   'image': 'T1_10',
#   'is_repeat': True,
#   'type': 'target',
#   'Image Index': 'Filler-903'},
#  {'trial_num': 42,
#   'image': 'F_S10',
#   'is_repeat': False,
#   'type': 'filler',
#   'Image Index': 'Target-2046'},
#  {'trial_num': 43,
#   'image': 'T2_1',
#   'is_repeat': False,
#   'type': 'target',
#   'Image Index': 'Filler-180'},
#  {'trial_num': 44,
#   'image': 'T1_1',
#   'is_repeat': True,
#   'type': 'target',
#   'Image Index': 'Filler-6188'},
#  {'trial_num': 45,
#   'image': 'T1_3',
#   'is_repeat': False,
#   'type': 'target',
#   'Image Index': 'Target-270'},
#  {'trial_num': 46,
#   'image': 'F_S6',
#   'is_repeat': False,
#   'type': 'filler',
#   'Image Index': 'Target-1905'},
#  {'trial_num': 47,
#   'image': 'T4_8',
#   'is_repeat': False,
#   'type': 'target',
#   'Image Index': 'Filler-624'},
#  {'trial_num': 48,
#   'image': 'F_S4',
#   'is_repeat': False,
#   'type': 'filler',
#   'Image Index': 'Target-1874'},
#  {'trial_num': 49,
#   'image': 'T2_13',
#   'is_repeat': False,
#   'type': 'target',
#   'Image Index': 'Filler-1943'},
#  {'trial_num': 50,
#   'image': 'F_S7',
#   'is_repeat': False,
#   'type': 'filler',
#   'Image Index': 'Target-1907'},
#  {'trial_num': 51,
#   'image': 'T2_10',
#   'is_repeat': True,
#   'type': 'target',
#   'Image Index': 'Filler-366'},
#  {'trial_num': 52,
#   'image': 'T1_4',
#   'is_repeat': False,
#   'type': 'target',
#   'Image Index': 'Filler-6435'},
#  {'trial_num': 53,
#   'image': 'T2_11',
#   'is_repeat': True,
#   'type': 'target',
#   'Image Index': 'Target-100'},
#  {'trial_num': 54,
#   'image': 'T1_5',
#   'is_repeat': True,
#   'type': 'target',
#   'Image Index': 'Filler-4507'},
#  {'trial_num': 55,
#   'image': 'T3_9',
#   'is_repeat': True,
#   'type': 'target',
#   'Image Index': 'Filler-7963'},
#  {'trial_num': 56,
#   'image': 'T3_3',
#   'is_repeat': False,
#   'type': 'target',
#   'Image Index': 'Target-1988'},
#  {'trial_num': 57,
#   'image': 'T4_5',
#   'is_repeat': True,
#   'type': 'target',
#   'Image Index': 'Target-673'},
#  {'trial_num': 58,
#   'image': 'T4_6',
#   'is_repeat': False,
#   'type': 'target',
#   'Image Index': 'Filler-7460'},
#  {'trial_num': 59,
#   'image': 'T2_4',
#   'is_repeat': True,
#   'type': 'target',
#   'Image Index': 'Filler-5605'},
#  {'trial_num': 60,
#   'image': 'T3_2',
#   'is_repeat': False,
#   'type': 'target',
#   'Image Index': 'Filler-2269'},
#  {'trial_num': 61,
#   'image': 'T2_7',
#   'is_repeat': False,
#   'type': 'target',
#   'Image Index': 'Filler-5741'},
#  {'trial_num': 62,
#   'image': 'F_S13',
#   'is_repeat': False,
#   'type': 'filler',
#   'Image Index': 'Target-2088'},
#  {'trial_num': 63,
#   'image': 'T1_11',
#   'is_repeat': False,
#   'type': 'target',
#   'Image Index': 'Filler-6285'},
#  {'trial_num': 64,
#   'image': 'T4_14',
#   'is_repeat': False,
#   'type': 'target',
#   'Image Index': 'Filler-6381'},
#  {'trial_num': 65,
#   'image': 'T2_12',
#   'is_repeat': True,
#   'type': 'target',
#   'Image Index': 'Filler-7840'},
#  {'trial_num': 66,
#   'image': 'T2_5',
#   'is_repeat': True,
#   'type': 'target',
#   'Image Index': 'Filler-511'},
#  {'trial_num': 67,
#   'image': 'T1_14',
#   'is_repeat': True,
#   'type': 'target',
#   'Image Index': 'Filler-2584'},
#  {'trial_num': 68,
#   'image': 'T4_12',
#   'is_repeat': True,
#   'type': 'target',
#   'Image Index': 'Target-675'},
#  {'trial_num': 69,
#   'image': 'T1_8',
#   'is_repeat': False,
#   'type': 'target',
#   'Image Index': 'Target-1021'},
#  {'trial_num': 70,
#   'image': 'T2_1',
#   'is_repeat': True,
#   'type': 'target',
#   'Image Index': 'Filler-180'},
#  {'trial_num': 71,
#   'image': 'T1_3',
#   'is_repeat': True,
#   'type': 'target',
#   'Image Index': 'Target-270'},
#  {'trial_num': 72,
#   'image': 'F_S18',
#   'is_repeat': False,
#   'type': 'filler',
#   'Image Index': 'Target-2198'},
#  {'trial_num': 73,
#   'image': 'T3_10',
#   'is_repeat': False,
#   'type': 'target',
#   'Image Index': 'Filler-656'},
#  {'trial_num': 74,
#   'image': 'T1_7',
#   'is_repeat': False,
#   'type': 'target',
#   'Image Index': 'Target-479'},
#  {'trial_num': 75,
#   'image': 'T3_6',
#   'is_repeat': False,
#   'type': 'target',
#   'Image Index': 'Target-609'},
#  {'trial_num': 76,
#   'image': 'F_S12',
#   'is_repeat': False,
#   'type': 'filler',
#   'Image Index': 'Target-2064'},
#  {'trial_num': 77,
#   'image': 'T2_13',
#   'is_repeat': True,
#   'type': 'target',
#   'Image Index': 'Filler-1943'},
#  {'trial_num': 78,
#   'image': 'T3_3',
#   'is_repeat': True,
#   'type': 'target',
#   'Image Index': 'Target-1988'},
#  {'trial_num': 79,
#   'image': 'T4_10',
#   'is_repeat': False,
#   'type': 'target',
#   'Image Index': 'Filler-1569'},
#  {'trial_num': 80,
#   'image': 'T4_7',
#   'is_repeat': False,
#   'type': 'target',
#   'Image Index': 'Filler-2084'},
#  {'trial_num': 81,
#   'image': 'T1_4',
#   'is_repeat': True,
#   'type': 'target',
#   'Image Index': 'Filler-6435'},
#  {'trial_num': 82,
#   'image': 'T3_11',
#   'is_repeat': False,
#   'type': 'target',
#   'Image Index': 'Filler-1159'},
#  {'trial_num': 83,
#   'image': 'T4_8',
#   'is_repeat': True,
#   'type': 'target',
#   'Image Index': 'Filler-624'},
#  {'trial_num': 84,
#   'image': 'T3_7',
#   'is_repeat': False,
#   'type': 'target',
#   'Image Index': 'Filler-15'},
#  {'trial_num': 85,
#   'image': 'T4_4',
#   'is_repeat': False,
#   'type': 'target',
#   'Image Index': 'Filler-2539'},
#  {'trial_num': 86,
#   'image': 'T2_15',
#   'is_repeat': False,
#   'type': 'target',
#   'Image Index': 'Filler-756'},
#  {'trial_num': 87,
#   'image': 'T4_14',
#   'is_repeat': True,
#   'type': 'target',
#   'Image Index': 'Filler-6381'},
#  {'trial_num': 88,
#   'image': 'F_S8',
#   'is_repeat': False,
#   'type': 'filler',
#   'Image Index': 'Target-1981'},
#  {'trial_num': 89,
#   'image': 'T3_2',
#   'is_repeat': True,
#   'type': 'target',
#   'Image Index': 'Filler-2269'},
#  {'trial_num': 90,
#   'image': 'T1_11',
#   'is_repeat': True,
#   'type': 'target',
#   'Image Index': 'Filler-6285'},
#  {'trial_num': 91,
#   'image': 'T3_8',
#   'is_repeat': False,
#   'type': 'target',
#   'Image Index': 'Filler-4687'},
#  {'trial_num': 92,
#   'image': 'T1_12',
#   'is_repeat': False,
#   'type': 'target',
#   'Image Index': 'Filler-5543'},
#  {'trial_num': 93,
#   'image': 'T1_2',
#   'is_repeat': False,
#   'type': 'target',
#   'Image Index': 'Target-1458'},
#  {'trial_num': 94,
#   'image': 'T3_14',
#   'is_repeat': False,
#   'type': 'target',
#   'Image Index': 'Filler-824'},
#  {'trial_num': 95,
#   'image': 'T4_6',
#   'is_repeat': True,
#   'type': 'target',
#   'Image Index': 'Filler-7460'},
#  {'trial_num': 96,
#   'image': 'T3_13',
#   'is_repeat': False,
#   'type': 'target',
#   'Image Index': 'Target-1306'},
#  {'trial_num': 97,
#   'image': 'T2_9',
#   'is_repeat': False,
#   'type': 'target',
#   'Image Index': 'Filler-1929'},
#  {'trial_num': 98,
#   'image': 'T2_8',
#   'is_repeat': False,
#   'type': 'target',
#   'Image Index': 'Target-1292'},
#  {'trial_num': 99,
#   'image': 'T2_7',
#   'is_repeat': True,
#   'type': 'target',
#   'Image Index': 'Filler-5741'},
#  {'trial_num': 100,
#   'image': 'T3_6',
#   'is_repeat': True,
#   'type': 'target',
#   'Image Index': 'Target-609'},
#  {'trial_num': 101,
#   'image': 'T1_7',
#   'is_repeat': True,
#   'type': 'target',
#   'Image Index': 'Target-479'},
#  {'trial_num': 102,
#   'image': 'T2_2',
#   'is_repeat': False,
#   'type': 'target',
#   'Image Index': 'Filler-4684'},
#  {'trial_num': 103,
#   'image': 'T3_10',
#   'is_repeat': True,
#   'type': 'target',
#   'Image Index': 'Filler-656'},
#  {'trial_num': 104,
#   'image': 'T4_11',
#   'is_repeat': False,
#   'type': 'target',
#   'Image Index': 'Target-1322'},
#  {'trial_num': 105,
#   'image': 'T3_1',
#   'is_repeat': False,
#   'type': 'target',
#   'Image Index': 'Filler-426'},
#  {'trial_num': 106,
#   'image': 'T2_6',
#   'is_repeat': False,
#   'type': 'target',
#   'Image Index': 'Filler-2883'},
#  {'trial_num': 107,
#   'image': 'T4_7',
#   'is_repeat': True,
#   'type': 'target',
#   'Image Index': 'Filler-2084'},
#  {'trial_num': 108,
#   'image': 'T4_10',
#   'is_repeat': True,
#   'type': 'target',
#   'Image Index': 'Filler-1569'},
#  {'trial_num': 109,
#   'image': 'T1_8',
#   'is_repeat': True,
#   'type': 'target',
#   'Image Index': 'Target-1021'},
#  {'trial_num': 110,
#   'image': 'T2_15',
#   'is_repeat': True,
#   'type': 'target',
#   'Image Index': 'Filler-756'},
#  {'trial_num': 111,
#   'image': 'T1_13',
#   'is_repeat': False,
#   'type': 'target',
#   'Image Index': 'Filler-1664'},
#  {'trial_num': 112,
#   'image': 'T1_9',
#   'is_repeat': False,
#   'type': 'target',
#   'Image Index': 'Filler-1828'},
#  {'trial_num': 113,
#   'image': 'T4_3',
#   'is_repeat': False,
#   'type': 'target',
#   'Image Index': 'Filler-4460'},
#  {'trial_num': 114,
#   'image': 'T3_11',
#   'is_repeat': True,
#   'type': 'target',
#   'Image Index': 'Filler-1159'},
#  {'trial_num': 115,
#   'image': 'T3_7',
#   'is_repeat': True,
#   'type': 'target',
#   'Image Index': 'Filler-15'},
#  {'trial_num': 116,
#   'image': 'T1_2',
#   'is_repeat': True,
#   'type': 'target',
#   'Image Index': 'Target-1458'},
#  {'trial_num': 117,
#   'image': 'T4_4',
#   'is_repeat': True,
#   'type': 'target',
#   'Image Index': 'Filler-2539'},
#  {'trial_num': 118,
#   'image': 'F_S5',
#   'is_repeat': False,
#   'type': 'filler',
#   'Image Index': 'Target-1903'},
#  {'trial_num': 119,
#   'image': 'T3_5',
#   'is_repeat': False,
#   'type': 'target',
#   'Image Index': 'Filler-7517'},
#  {'trial_num': 120,
#   'image': 'T3_15',
#   'is_repeat': False,
#   'type': 'target',
#   'Image Index': 'Filler-358'},
#  {'trial_num': 121,
#   'image': 'T2_9',
#   'is_repeat': True,
#   'type': 'target',
#   'Image Index': 'Filler-1929'},
#  {'trial_num': 122,
#   'image': 'F_R5',
#   'is_repeat': False,
#   'type': 'filler',
#   'Image Index': 'Target-120'},
#  {'trial_num': 123,
#   'image': 'T2_14',
#   'is_repeat': False,
#   'type': 'target',
#   'Image Index': 'Target-1179'},
#  {'trial_num': 124,
#   'image': 'T3_8',
#   'is_repeat': True,
#   'type': 'target',
#   'Image Index': 'Filler-4687'},
#  {'trial_num': 125,
#   'image': 'F_R5',
#   'is_repeat': True,
#   'type': 'filler',
#   'Image Index': 'Target-120'},
#  {'trial_num': 126,
#   'image': 'T4_11',
#   'is_repeat': True,
#   'type': 'target',
#   'Image Index': 'Target-1322'},
#  {'trial_num': 127,
#   'image': 'T3_1',
#   'is_repeat': True,
#   'type': 'target',
#   'Image Index': 'Filler-426'},
#  {'trial_num': 128,
#   'image': 'F_S17',
#   'is_repeat': False,
#   'type': 'filler',
#   'Image Index': 'Target-2191'},
#  {'trial_num': 129,
#   'image': 'T1_12',
#   'is_repeat': True,
#   'type': 'target',
#   'Image Index': 'Filler-5543'},
#  {'trial_num': 130,
#   'image': 'T3_14',
#   'is_repeat': True,
#   'type': 'target',
#   'Image Index': 'Filler-824'},
#  {'trial_num': 131,
#   'image': 'F_S16',
#   'is_repeat': False,
#   'type': 'filler',
#   'Image Index': 'Target-2179'},
#  {'trial_num': 132,
#   'image': 'F_S11',
#   'is_repeat': False,
#   'type': 'filler',
#   'Image Index': 'Target-2055'},
#  {'trial_num': 133,
#   'image': 'T3_13',
#   'is_repeat': True,
#   'type': 'target',
#   'Image Index': 'Target-1306'},
#  {'trial_num': 134,
#   'image': 'F_S14',
#   'is_repeat': False,
#   'type': 'filler',
#   'Image Index': 'Target-2140'},
#  {'trial_num': 135,
#   'image': 'T2_8',
#   'is_repeat': True,
#   'type': 'target',
#   'Image Index': 'Target-1292'},
#  {'trial_num': 136,
#   'image': 'T1_9',
#   'is_repeat': True,
#   'type': 'target',
#   'Image Index': 'Filler-1828'},
#  {'trial_num': 137,
#   'image': 'F_R2',
#   'is_repeat': False,
#   'type': 'filler',
#   'Image Index': 'Target-35'},
#  {'trial_num': 138,
#   'image': 'T1_13',
#   'is_repeat': True,
#   'type': 'target',
#   'Image Index': 'Filler-1664'},
#  {'trial_num': 139,
#   'image': 'F_R2',
#   'is_repeat': True,
#   'type': 'filler',
#   'Image Index': 'Target-35'},
#  {'trial_num': 140,
#   'image': 'T2_2',
#   'is_repeat': True,
#   'type': 'target',
#   'Image Index': 'Filler-4684'},
#  {'trial_num': 141,
#   'image': 'F_S15',
#   'is_repeat': False,
#   'type': 'filler',
#   'Image Index': 'Target-2159'},
#  {'trial_num': 142,
#   'image': 'F_S19',
#   'is_repeat': False,
#   'type': 'filler',
#   'Image Index': 'Target-2199'},
#  {'trial_num': 143,
#   'image': 'F_S2',
#   'is_repeat': False,
#   'type': 'filler',
#   'Image Index': 'Target-1858'},
#  {'trial_num': 144,
#   'image': 'T4_15',
#   'is_repeat': False,
#   'type': 'target',
#   'Image Index': 'Filler-7486'},
#  {'trial_num': 145,
#   'image': 'T3_15',
#   'is_repeat': True,
#   'type': 'target',
#   'Image Index': 'Filler-358'},
#  {'trial_num': 146,
#   'image': 'F_R1',
#   'is_repeat': False,
#   'type': 'filler',
#   'Image Index': 'Target-13'},
#  {'trial_num': 147,
#   'image': 'T2_14',
#   'is_repeat': True,
#   'type': 'target',
#   'Image Index': 'Target-1179'},
#  {'trial_num': 148,
#   'image': 'F_R1',
#   'is_repeat': True,
#   'type': 'filler',
#   'Image Index': 'Target-13'},
#  {'trial_num': 149,
#   'image': 'T3_5',
#   'is_repeat': True,
#   'type': 'target',
#   'Image Index': 'Filler-7517'},
#  {'trial_num': 150,
#   'image': 'T4_3',
#   'is_repeat': True,
#   'type': 'target',
#   'Image Index': 'Filler-4460'}]
